# %%
import nltk, re, string, random
from nltk.tag import pos_tag
from nltk.corpus import twitter_samples, stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk import FreqDist, classify, NaiveBayesClassifier
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('twitter_samples')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\15-6-2023\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\15-6-2023\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\15-6-2023\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     C:\Users\15-6-2023\AppData\Roaming\nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\15-6-2023\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\15-6-2023\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\15-6-2023\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
positive_tweets = twitter_samples.strings('positive_tweets.json')
negative_tweets = twitter_samples.strings('negative_tweets.json')

text = twitter_samples.strings('tweets.20150430-223406.json')
tweet_tokens = twitter_samples.tokenized('positive_tweets.json')

# %%
len(positive_tweets), len(negative_tweets)
# Out:
# (5000, 5000)

# %%
positive_tweets[500]
# Out:
# 'Dang that is some rad @AbzuGame #fanart! :D https://t.co/bI8k8tb9ht'

# %%
positive_tweets[0], tweet_tokens[0]
# Out:
# ('#FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)',
#  ['#FollowFriday',
#   '@France_Inte',
#   '@PKuchly57',
#   '@Milipol_Paris',
#   'for',
#   'being',
#   'top',
#   'engaged',
#   'members',
#   'in',
#   'my',
#   'community',
#   'this',
#   'week',
#   ':)'])

# %%
print(pos_tag(tweet_tokens[0]))
# Out:
# [('#FollowFriday', 'JJ'), ('@France_Inte', 'NNP'), ('@PKuchly57', 'NNP'), ('@Milipol_Paris', 'NNP'), ('for', 'IN'), ('being', 'VBG'), ('top', 'JJ'), ('engaged', 'VBN'), ('members', 'NNS'), ('in', 'IN'), ('my', 'PRP$'), ('community', 'NN'), ('this', 'DT'), ('week', 'NN'), (':)', 'NN')]

# %% [markdown]
# # Cleaning Data

# %%
def lemmatize_sentence(tokens):
    lemmatizer = WordNetLemmatizer()
    lemmatized_sentence = []

    for word, tag in pos_tag(tokens):
        if tag.startswith('NN'):
            pos = 'n'
        elif tag.startswith('VB'):
            pos = 'v'
        else:
            pos = 'a'
        lemmatized_sentence.append(lemmatizer.lemmatize(word, pos))
    return lemmatized_sentence

# %%
tweet_tokens[0], lemmatize_sentence(tweet_tokens[0])
# Out:
# (['#FollowFriday',
#   '@France_Inte',
#   '@PKuchly57',
#   '@Milipol_Paris',
#   'for',
#   'being',
#   'top',
#   'engaged',
#   'members',
#   'in',
#   'my',
#   'community',
#   'this',
#   'week',
#   ':)'],
#  ['#FollowFriday',
#   '@France_Inte',
#   '@PKuchly57',
#   '@Milipol_Paris',
#   'for',
#   'be',
#   'top',
#   'engage',
#   'member',
#   'in',
#   'my',
#   'community',
#   'this',
#   'week',
#   ':)'])

# %%
def remove_noise(tweet_tokens, stop_words = () ):

    cleaned_tokens = []

    for token, tag in pos_tag(tweet_tokens):

        token = re.sub('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+#]|[!*\(\),]|'\
                      '(?:%[0-9a-fA-F][0-9a-fA-F]))+', '', token)

        token = re.sub('(@[A-Za-z0-9_]+)0', '', token)

        if tag.startswith('NN'):
            pos = 'n'
        elif tag.startswith('VB'):
            pos = 'v'
        else:
            pos = 'a'

        lemmatizer = WordNetLemmatizer()

        token = lemmatizer.lemmatize(token, pos)

        if len(token) > 0 and token not in string.punctuation and token.lower() not in stop_words:

            cleaned_tokens.append(token.lower())

    return cleaned_tokens
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\('
# <>:7: SyntaxWarning: invalid escape sequence '\('
# C:\Users\15-6-2023\AppData\Local\Temp\ipykernel_18520\2114586792.py:7: SyntaxWarning: invalid escape sequence '\('
#   token = re.sub('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+#]|[!*\(\),]|'\

# %%
stopwords = stopwords.words('english')

# %%
remove_noise(tweet_tokens[0], stopwords)
# Out:
# ['#followfriday',
#  '@france_inte',
#  '@pkuchly57',
#  '@milipol_paris',
#  'top',
#  'engage',
#  'member',
#  'community',
#  'week',
#  ':)']

# %%
tweet_tokens[0]
# Out:
# ['#FollowFriday',
#  '@France_Inte',
#  '@PKuchly57',
#  '@Milipol_Paris',
#  'for',
#  'being',
#  'top',
#  'engaged',
#  'members',
#  'in',
#  'my',
#  'community',
#  'this',
#  'week',
#  ':)']

# %%
remove_noise(tweet_tokens[300], stopwords)
# Out:
# ['stats', 'day', 'arrive', '2', 'new', 'follower', 'unfollowers', ':)', 'via']

# %%
tweet_tokens[300]
# Out:
# ['Stats',
#  'for',
#  'the',
#  'day',
#  'have',
#  'arrived',
#  '.',
#  '2',
#  'new',
#  'followers',
#  'and',
#  'NO',
#  'unfollowers',
#  ':)',
#  'via',
#  'http://t.co/xxlXs6xYwe',
#  '.']

# %%
positive_tweet_tokens = twitter_samples.tokenized('positive_tweets.json')
negative_tweet_tokens = twitter_samples.tokenized('negative_tweets.json')

# %%
positive_cleaned_tokens_list = []
negative_cleaned_tokens_list = []

for token in positive_tweet_tokens:

    positive_cleaned_tokens_list.append(remove_noise(token, stopwords))

for token in negative_tweet_tokens:
    
    negative_cleaned_tokens_list.append(remove_noise(token, stopwords))

# %%
positive_tweet_tokens[500], positive_cleaned_tokens_list[500]
# Out:
# (['Dang',
#   'that',
#   'is',
#   'some',
#   'rad',
#   '@AbzuGame',
#   '#fanart',
#   '!',
#   ':D',
#   'https://t.co/bI8k8tb9ht'],
#  ['dang', 'rad', '@abzugame', '#fanart', ':d'])

# %%
def get_all_words(cleaned_tokens_list):

    for tokens in cleaned_tokens_list:
        for token in tokens:
            yield token

all_pos_token = get_all_words(positive_cleaned_tokens_list)

# %%
all_pos_token
# Out:
# <generator object get_all_words at 0x000001D04EE60AD0>

# %%
feq_dist_pos = FreqDist(all_pos_token)

# %%
print(feq_dist_pos.most_common(20))
# Out:
# [(':)', 3691), (':-)', 701), (':d', 658), ('thanks', 388), ('follow', 357), ('love', 333), ('...', 290), ('good', 283), ('get', 263), ('thank', 253), ('u', 245), ('day', 242), ('like', 229), ('see', 195), ('happy', 192), ("i'm", 183), ('great', 175), ('hi', 173), ('go', 167), ('back', 163)]

# %%
def get_tweets_for_model(cleaned_tokens_list):

    for tweet_tokens in cleaned_tokens_list:
        yield dict( [token, True] for token in tweet_tokens)

positive_tokens_for_model = get_tweets_for_model(positive_cleaned_tokens_list)
negative_tokens_for_model = get_tweets_for_model(negative_cleaned_tokens_list)

# %%
positive_tokens_for_model
# Out:
# <generator object get_tweets_for_model at 0x000001D04F5A5620>

# %%
positive_dataset = [(tweet_dict, "Positive")
                   for tweet_dict in positive_tokens_for_model]

negative_dataset = [(tweet_dict, "Negative")
                   for tweet_dict in negative_tokens_for_model]

dataset = positive_dataset + negative_dataset

# %%
dataset
# Out:
# [({'#followfriday': True,
#    '@france_inte': True,
#    '@pkuchly57': True,
#    '@milipol_paris': True,
#    'top': True,
#    'engage': True,
#    'member': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'@lamb2ja': True,
#    'hey': True,
#    'james': True,
#    'odd': True,
#    ':/': True,
#    'please': True,
#    'call': True,
#    'contact': True,
#    'centre': True,
#    '02392441234': True,
#    'able': True,
#    'assist': True,
#    ':)': True,
#    'many': True,
#    'thanks': True},
#   'Positive'),
#  ({'@despiteofficial': True,
#    'listen': True,
#    'last': True,
#    'night': True,
#    ':)': True,
#    'bleed': True,
#    'amazing': True,
#    'track': True,
#    'scotland': True},
#   'Positive'),
#  ({'@97sides': True, 'congrats': True, ':)': True}, 'Positive'),
#  ({'yeaaaah': True,
#    'yippppy': True,
#    'accnt': True,
#    'verify': True,
#    'rqst': True,
#    'succeed': True,
#    'get': True,
#    'blue': True,
#    'tick': True,
#    'mark': True,
#    'fb': True,
#    'profile': True,
#    ':)': True,
#    '15': True,
#    'day': True},
#   'Positive'),
#  ({'@bhaktisbanter': True,
#    '@pallaviruhail': True,
#    'one': True,
#    'irresistible': True,
#    ':)': True,
#    '#flipkartfashionfriday': True},
#   'Positive'),
#  ({'like': True,
#    'keep': True,
#    'lovely': True,
#    'customer': True,
#    'wait': True,
#    'long': True,
#    'hope': True,
#    'enjoy': True,
#    'happy': True,
#    'friday': True,
#    'lwwf': True,
#    ':)': True},
#   'Positive'),
#  ({'@impatientraider': True,
#    'second': True,
#    'thought': True,
#    '’': True,
#    'enough': True,
#    'time': True,
#    'dd': True,
#    ':)': True,
#    'new': True,
#    'short': True,
#    'enter': True,
#    'system': True,
#    'sheep': True,
#    'must': True,
#    'buy': True},
#   'Positive'),
#  ({'jgh': True, 'go': True, 'bayan': True, ':d': True, 'bye': True},
#   'Positive'),
#  ({'act': True,
#    'mischievousness': True,
#    'call': True,
#    'etl': True,
#    'layer': True,
#    'in-house': True,
#    'warehouse': True,
#    'app': True,
#    'katamari': True,
#    'well': True,
#    '…': True,
#    'name': True,
#    'imply': True,
#    ':p': True},
#   'Positive'),
#  ({'#followfriday': True,
#    '@wncer1': True,
#    '@defense_gouv': True,
#    'top': True,
#    'influencers': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'love': True,
#    'big': True,
#    '...': True,
#    'juicy': True,
#    'selfies': True,
#    ':)': True},
#   'Positive'),
#  ({'@mish23615351': True,
#    'follow': True,
#    '@jnlazts': True,
#    'u': True,
#    'back': True,
#    ':)': True},
#   'Positive'),
#  ({'@jjulieredburn': True,
#    'perfect': True,
#    'already': True,
#    'know': True,
#    "what's": True,
#    'wait': True,
#    ':)': True},
#   'Positive'),
#  ({'great': True,
#    'new': True,
#    'opportunity': True,
#    'junior': True,
#    'triathletes': True,
#    'age': True,
#    '12': True,
#    '13': True,
#    'gatorade': True,
#    'series': True,
#    'get': True,
#    'entry': True,
#    ':)': True},
#   'Positive'),
#  ({'laying': True,
#    'greeting': True,
#    'card': True,
#    'range': True,
#    'print': True,
#    'today': True,
#    'love': True,
#    'job': True,
#    ':-)': True},
#   'Positive'),
#  ({"friend's": True,
#    'lunch': True,
#    '...': True,
#    'yummmm': True,
#    ':)': True,
#    '#nostalgia': True,
#    '#tbs': True,
#    '#ku': True},
#   'Positive'),
#  ({'@rookiesenpai': True,
#    '@arcadester': True,
#    'id': True,
#    'conflict': True,
#    'thanks': True,
#    'help': True,
#    ':d': True,
#    "here's": True,
#    'screenshot': True,
#    'work': True},
#   'Positive'),
#  ({'@oohdawg_': True, 'hi': True, 'liv': True, ':)': True}, 'Positive'),
#  ({'hello': True,
#    'need': True,
#    'know': True,
#    'something': True,
#    'u': True,
#    'fm': True,
#    'twitter': True,
#    '—': True,
#    'sure': True,
#    'thing': True,
#    ':)': True,
#    'dm': True,
#    'x': True},
#   'Positive'),
#  ({'#followfriday': True,
#    '@mbandscott_': True,
#    '@eric_fle': True,
#    '@pointsolutions3': True,
#    'top': True,
#    'new': True,
#    'follower': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'@rossbreadmore': True,
#    "i've": True,
#    'hear': True,
#    'four': True,
#    'seasons': True,
#    'pretty': True,
#    'dope': True,
#    'penthouse': True,
#    'obvs': True,
#    '#gobigorgohome': True,
#    'fun': True,
#    "y'all": True,
#    ':)': True},
#   'Positive'),
#  ({'@gculloty87': True,
#    'yeah': True,
#    'suppose': True,
#    'lol': True,
#    'chat': True,
#    'bit': True,
#    'x': True,
#    ':)': True},
#   'Positive'),
#  ({'hello': True,
#    ':)': True,
#    'get': True,
#    'youth': True,
#    'job': True,
#    'opportunities': True,
#    'follow': True,
#    '@tolajobjobs': True,
#    '1': True},
#   'Positive'),
#  ({'💅🏽': True, '💋': True, ':)': True, 'see': True, 'year': True}, 'Positive'),
#  ({'@bosslogic': True,
#    '@amellywood': True,
#    '@cw_arrow': True,
#    '@arrowwriters': True,
#    'thank': True,
#    ':-)': True},
#   'Positive'),
#  ({'@johngutierrez1': True,
#    'hope': True,
#    'rest': True,
#    'night': True,
#    'go': True,
#    'quickly': True,
#    '...': True,
#    'bed': True,
#    'get': True,
#    'music': True,
#    'fix': True,
#    'time': True,
#    'dream': True,
#    ':)': True},
#   'Positive'),
#  ({'spiritual': True,
#    'ritual': True,
#    'festival': True,
#    'népal': True,
#    'beginning': True,
#    'line-up': True,
#    ':)': True,
#    'leave': True,
#    'see': True,
#    '...': True},
#   'Positive'),
#  ({'@ke7zum': True,
#    'hey': True,
#    'sarah': True,
#    'send': True,
#    'us': True,
#    'email': True,
#    'bitsy@bitdefender.com': True,
#    "we'll": True,
#    'help': True,
#    'asap': True,
#    ':)': True},
#   'Positive'),
#  ({'@izzkamilhalda': True, 'lols': True, ':d': True}, 'Positive'),
#  ({'kik': True,
#    'hatessuce': True,
#    '32429': True,
#    '#kik': True,
#    '#kikme': True,
#    '#lgbt': True,
#    '#tinder': True,
#    '#nsfw': True,
#    '#akua': True,
#    '#cumshot': True,
#    ':)': True},
#   'Positive'),
#  ({'@kalinwhite': True, 'come': True, 'house': True, ':)': True}, 'Positive'),
#  ({'#nsn_supplements': True,
#    'effective': True,
#    'press': True,
#    'release': True,
#    'distribution': True,
#    'result': True,
#    ':)': True,
#    'link': True,
#    'remove': True,
#    '#pressrelease': True,
#    '#newsdistribution': True},
#   'Positive'),
#  ({'hi': True,
#    'bam': True,
#    '@barsandmelody': True,
#    'follow': True,
#    'bestfriend': True,
#    '@969horan696': True,
#    'love': True,
#    'lot': True,
#    ':)': True,
#    'see': True,
#    'warsaw': True,
#    '<3': True,
#    'x46': True},
#   'Positive'),
#  ({'everyone': True,
#    'watch': True,
#    'documentary': True,
#    'earthlings': True,
#    'youtube': True,
#    ':-)': True},
#   'Positive'),
#  ({'@jamiefigsxx': True,
#    'follow': True,
#    '@jnlazts': True,
#    'u': True,
#    'back': True,
#    ':)': True},
#   'Positive'),
#  ({'#followfriday': True,
#    '@michelbauza': True,
#    '@invataonline': True,
#    'top': True,
#    'support': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'buuuuuuuut': True, 'oh': True, 'well': True, ':-)': True}, 'Positive'),
#  ({'@leisuremarkltd': True,
#    '@noshandquaff': True,
#    '@aktarislam': True,
#    '@keanebrands': True,
#    '@heritagesilver': True,
#    'look': True,
#    'forward': True,
#    'visit': True,
#    'next': True,
#    'week': True,
#    '#letsgetmessy': True,
#    'jo': True,
#    ':-)': True},
#   'Positive'),
#  ({'@sehunshinedaily': True,
#    'make': True,
#    'u': True,
#    'feel': True,
#    'good': True,
#    'never': True,
#    'see': True,
#    'anyone': True,
#    'kpop': True,
#    'flesh': True,
#    ':d': True},
#   'Positive'),
#  ({'12': True,
#    '@cathstaincliffe': True,
#    'good': True,
#    'girl': True,
#    'best': True,
#    'wish': True,
#    ':-)': True},
#   'Positive'),
#  ({'@_kimimi': True,
#    'great': True,
#    'enough': True,
#    'reason': True,
#    'listen': True,
#    'one': True,
#    'epic': True,
#    'soundtrack': True,
#    ':d': True},
#   'Positive'),
#  ({'@aquadesigngroup': True,
#    'thank': True,
#    'shout': True,
#    'great': True,
#    'friday': True,
#    ':)': True},
#   'Positive'),
#  ({'add': True,
#    'video': True,
#    '@youtube': True,
#    'playlist': True,
#    'im': True,
#    'back': True,
#    'twitch': True,
#    'today': True,
#    'go': True,
#    'league': True,
#    ':)': True,
#    '1': True,
#    '4': True},
#   'Positive'),
#  ({'would': True,
#    'love': True,
#    'see': True,
#    'dear': True,
#    '#jordan': True,
#    ':)': True,
#    'wait': True,
#    '@firdoz': True,
#    '@visitjordan': True,
#    '@dannyprol': True},
#   'Positive'),
#  ({'@abnormal_ana92': True,
#    'oh': True,
#    'okay': True,
#    ':d': True,
#    'thanks': True},
#   'Positive'),
#  ({'@sssniperwolf': True,
#    'like': True,
#    'fake': True,
#    'gameplays': True,
#    ';)': True,
#    'haha': True,
#    'im': True,
#    'kidding': True,
#    'good': True,
#    'stuff': True,
#    ':)': True},
#   'Positive'),
#  ({'@dennislami': True,
#    '@dicle_aygur': True,
#    'yeah': True,
#    'exactly': True,
#    ':)': True},
#   'Positive'),
#  ({'new': True,
#    'product': True,
#    'line': True,
#    '#etsy': True,
#    'shop': True,
#    'check': True,
#    ':)': True,
#    '#boxroomcrafts': True},
#   'Positive'),
#  ({'@peakyourmind': True,
#    'hope': True,
#    'vacation': True,
#    'go': True,
#    'great': True,
#    ':d': True},
#   'Positive'),
#  ({'@groovinshawn': True,
#    'rechargeable': True,
#    'normally': True,
#    'come': True,
#    'charger': True,
#    'u': True,
#    'buy': True,
#    ':)': True},
#   'Positive'),
#  ({'#followfriday': True,
#    '@france_espana': True,
#    '@reglisse_menthe': True,
#    '@cci_inter': True,
#    'top': True,
#    'engage': True,
#    'member': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'well': True,
#    'asleep': True,
#    'one': True,
#    'talk': True,
#    'sooo': True,
#    'someone': True,
#    'text': True,
#    ':)': True},
#   'Positive'),
#  ({'@brynybrath': True,
#    '@smallcappy': True,
#    'yes': True,
#    'suppose': True,
#    'bet': True,
#    "he'll": True,
#    'blue': True,
#    'fit': True,
#    'hear': True,
#    'speech': True,
#    'today': True,
#    'pity': True,
#    ':-)': True},
#   'Positive'),
#  ({'green': True,
#    'garden': True,
#    'midnight': True,
#    'sun': True,
#    'beautiful': True,
#    'canal': True,
#    'dasvidaniya': True,
#    'till': True,
#    'next': True,
#    'visit': True,
#    ':)': True},
#   'Positive'),
#  ({'@keithrparsons': True,
#    'scout': True,
#    'sg': True,
#    'future': True,
#    'wlan': True,
#    'pro': True,
#    'conference': True,
#    'asia': True,
#    ':)': True},
#   'Positive'),
#  ({'@cecilie_hell': True,
#    'evilangel': True,
#    '@wazimotometal': True,
#    '@durooooooo': True,
#    '@spigranty': True,
#    'good': True,
#    'u': True,
#    'change': True,
#    'lollipop': True,
#    '🍭': True,
#    ':)': True},
#   'Positive'),
#  ({'<3': True, 'u': True, 'nez': True, ':)': True, '#agnezmo': True},
#   'Positive'),
#  ({'@littlemix': True,
#    'follow': True,
#    'please': True,
#    ':)': True,
#    'big': True,
#    'dream': True},
#   'Positive'),
#  ({'@elemaaan': True, 'oley': True, ':d': True}, 'Positive'),
#  ({'@cowokaddict': True,
#    'mama': True,
#    'reason': True,
#    'stand': True,
#    'strong': True,
#    ':)': True},
#   'Positive'),
#  ({'@macatangayapril': True,
#    'follow': True,
#    '@jnlazts': True,
#    'u': True,
#    'back': True,
#    ':)': True},
#   'Positive'),
#  ({'@tk_kjk_kndr': True,
#    '@boukendreamer': True,
#    'oh': True,
#    'god': True,
#    'misty': True,
#    'baby': True,
#    'cute': True,
#    ':d': True},
#   'Positive'),
#  ({'@bhaktisbanter': True,
#    'love': True,
#    'blue': True,
#    ':)': True,
#    '#flipkartfashionfriday': True},
#   'Positive'),
#  ({'@carcassdrop': True,
#    'woohoo': True,
#    "can't": True,
#    'wait': True,
#    ':)': True,
#    'sign': True,
#    'yet': True,
#    'still': True,
#    'think': True,
#    'mka': True},
#   'Positive'),
#  ({'liam': True, 'access': True, ':)': True}, 'Positive'),
#  ({'@syuhxdxtengku': True, 'welcome': True, ':)': True}, 'Positive'),
#  ({'stats': True,
#    'day': True,
#    'arrive': True,
#    '1': True,
#    'new': True,
#    'follower': True,
#    'unfollowers': True,
#    ':)': True,
#    'via': True},
#   'Positive'),
#  ({'@sluttywife2': True,
#    'surprise': True,
#    '...': True,
#    'amazing': True,
#    'figure': True,
#    ':)': True},
#   'Positive'),
#  ({'#followfriday': True,
#    '@murtishaw': True,
#    '@aqui_fr': True,
#    '@frtechstartups': True,
#    'top': True,
#    'influencers': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'#happybirthdayemilybett': True,
#    '@emilybett': True,
#    ':)': True,
#    'wishing': True,
#    'best': True,
#    'beautiful': True,
#    'sweet': True,
#    'talented': True,
#    'amaze': True,
#    '…': True},
#   'Positive'),
#  ({'2': True,
#    'plan': True,
#    'day': True,
#    'drain': True,
#    'great': True,
#    ':)': True},
#   'Positive'),
#  ({'@x123456789tine': True,
#    '@5sos_fahupdates': True,
#    'gotta': True,
#    'love': True,
#    'timezones': True,
#    ':p': True},
#   'Positive'),
#  ({'parent': True,
#    'proud': True,
#    '—': True,
#    'lol': True,
#    'least': True,
#    ':d': True,
#    'maybe': True,
#    'sometimes': True,
#    'get': True,
#    'happy': True,
#    'grade': True,
#    'al': True,
#    '...': True},
#   'Positive'),
#  ({'grande': True, ':)': True}, 'Positive'),
#  ({'manila_bro': True,
#    'choose': True,
#    'follow': True,
#    'twitter': True,
#    'thanks': True,
#    ':)': True},
#   'Positive'),
#  ({'@syazwanzainal': True,
#    'sure': True,
#    'let': True,
#    'know': True,
#    'around': True,
#    '..': True,
#    'side': True,
#    'world': True,
#    '#eh': True,
#    'u': True,
#    'take': True,
#    'care': True,
#    ':-)': True},
#   'Positive'),
#  ({'#followfriday': True,
#    '@michae1green': True,
#    '@superninjaalan': True,
#    '@doug_laney': True,
#    'top': True,
#    'new': True,
#    'follower': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'finally': True, 'fuck': True, 'weekend': True, ':)': True}, 'Positive'),
#  ({'real': True, ':)': True}, 'Positive'),
#  ({'@lolesportspedia': True, 'thanks': True, ':d': True}, 'Positive'),
#  ({'hi': True,
#    'bam': True,
#    '@barsandmelody': True,
#    'follow': True,
#    'bestfriend': True,
#    '@969horan696': True,
#    'love': True,
#    'lot': True,
#    ':)': True,
#    'see': True,
#    'warsaw': True,
#    '<3': True,
#    'x45': True},
#   'Positive'),
#  ({'yes': True,
#    'joined': True,
#    '#hushedcallwithfraydoe': True,
#    'call': True,
#    'gift': True,
#    '@_fraydoe': True,
#    '<3': True,
#    'gotta': True,
#    'get': True,
#    '@hushedapp': True,
#    ':d': True},
#   'Positive'),
#  ({'@yaslarry': True, 'yeahhh': True, ':)': True}, 'Positive'),
#  ({'dm': True, 'make': True, 'night': True, 'good': True, ':)': True},
#   'Positive'),
#  ({'join': True,
#    '#hushedpinwithsammy': True,
#    'event': True,
#    ':d': True,
#    'might': True,
#    'get': True,
#    'text': True,
#    '@sammywilk': True,
#    'day': True,
#    'luv': True,
#    'u': True,
#    '@hushedapp': True},
#   'Positive'),
#  ({'would': True,
#    'really': True,
#    'appreciate': True,
#    'share': True,
#    'video': True,
#    'around': True,
#    ':)': True},
#   'Positive'),
#  ({'hello': True,
#    ':)': True,
#    'get': True,
#    'youth': True,
#    'job': True,
#    'opportunities': True,
#    'follow': True,
#    '@tolajobjobs': True},
#   'Positive'),
#  ({'@tomparker': True,
#    'oh': True,
#    'wow': True,
#    'beautiful': True,
#    'tom': True,
#    ':)': True},
#   'Positive'),
#  ({'love': True, '@darlingixhai22': True, '@syreenanne': True, ':)': True},
#   'Positive'),
#  ({'add': True,
#    'video': True,
#    '@youtube': True,
#    'playlist': True,
#    'im': True,
#    'back': True,
#    'twitch': True,
#    'today': True,
#    'go': True,
#    'league': True,
#    ':)': True,
#    '1': True,
#    '3': True},
#   'Positive'),
#  ({'#followfriday': True,
#    '@americanograin': True,
#    '@pecomep': True,
#    '@apaulicand': True,
#    'top': True,
#    'support': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'follow': True, '@jnlazts': True, 'u': True, 'back': True, ':)': True},
#   'Positive'),
#  ({'gym': True,
#    'monday': True,
#    "can't": True,
#    'wait': True,
#    ':)': True,
#    'likes': True},
#   'Positive'),
#  ({'@harnilizalouis': True,
#    'hey': True,
#    "here's": True,
#    'invite': True,
#    'join': True,
#    'scope': True,
#    'influencer': True,
#    ':)': True},
#   'Positive'),
#  ({'friend': True, 'know': True, ':)': True}, 'Positive'),
#  ({'wait': True, 'nude': True, ':-)': True}, 'Positive'),
#  ({'@jacobwhitesides': True, 'go': True, 'sleep': True, 'u': True, ':)': True},
#   'Positive'),
#  ({'stats': True,
#    'day': True,
#    'arrive': True,
#    '1': True,
#    'new': True,
#    'follower': True,
#    'unfollowers': True,
#    ':)': True,
#    'via': True},
#   'Positive'),
#  ({'birthday': True, 'week': True, 'today': True, ':d': True}, 'Positive'),
#  ({'@metalgear_jp': True,
#    '@kojima_hideo': True,
#    'want': True,
#    't-shirts': True,
#    'cool': True,
#    ':d': True},
#   'Positive'),
#  ({'@axerade': True,
#    'haw': True,
#    'phela': True,
#    'look': True,
#    'like': True,
#    'mom': True,
#    'obviously': True,
#    ':)': True},
#   'Positive'),
#  ({'@zaynmalik': True,
#    'prince': True,
#    'charm': True,
#    'stage': True,
#    ':)': True,
#    'x': True},
#   'Positive'),
#  ({'really': True, 'good': True, 'luck': True, ':)': True}, 'Positive'),
#  ({'stats': True,
#    'day': True,
#    'arrive': True,
#    '1': True,
#    'new': True,
#    'follower': True,
#    'unfollowers': True,
#    ':)': True,
#    'via': True},
#   'Positive'),
#  ({'#followfriday': True,
#    '@straz_das': True,
#    '@dcarsoncpa': True,
#    'top': True,
#    'engage': True,
#    'member': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'@twentyonepilots': True,
#    '@fujirock_jp': True,
#    'tyler': True,
#    'hipster': True,
#    'glass': True,
#    ':d': True},
#   'Positive'),
#  ({'@martyrafenstein': True,
#    'hey': True,
#    'marty': True,
#    'glad': True,
#    'see': True,
#    'twitter': True,
#    ':)': True},
#   'Positive'),
#  ({'@ukbusinesslunch': True,
#    'hi': True,
#    'join': True,
#    'today': True,
#    ':)': True},
#   'Positive'),
#  ({'@lafitnessukhelp': True, 'thanks': True, ':-)': True}, 'Positive'),
#  ({'already': True,
#    'afternoon': True,
#    'let': True,
#    'read': True,
#    'al': True,
#    'kahfi': True,
#    'day': True,
#    'finish': True,
#    ':)': True},
#   'Positive'),
#  ({'ohmyg': True,
#    'yaya': True,
#    'dub': True,
#    '@mainedcm': True,
#    'im': True,
#    'stalk': True,
#    'ig': True,
#    'accnt': True,
#    '..': True,
#    'gondooo': True,
#    'moo': True,
#    'tologooo': True,
#    ':)': True,
#    'haha': True},
#   'Positive'),
#  ({'@rozbabes': True,
#    "here's": True,
#    'invite': True,
#    'become': True,
#    'scope': True,
#    'influencer': True,
#    ':)': True,
#    'details': True},
#   'Positive'),
#  ({'#followfriday': True,
#    '@ngourd': True,
#    '@locita': True,
#    '@d_robert_kelly': True,
#    'top': True,
#    'influencers': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'@kevinthewhippet': True,
#    '@cassie_spaniel': True,
#    '@bracken_nelson': True,
#    '@bellisimobella1': True,
#    '@spanielharry': True,
#    'thanks': True,
#    ':)': True,
#    'zzz': True,
#    'xx': True},
#   'Positive'),
#  ({'physiotherapy': True,
#    'friday': True,
#    'hashtag': True,
#    'today': True,
#    'custom': True,
#    ':-)': True},
#   'Positive'),
#  ({'@cjlopez21': True,
#    'know': True,
#    '💪': True,
#    'monica': True,
#    'miss': True,
#    'yeah': True,
#    'sound': True,
#    'good': True,
#    ':)': True},
#   'Positive'),
#  ({'good': True,
#    'morning': True,
#    'beautiful': True,
#    ':)': True,
#    "that's": True,
#    'take': True},
#   'Positive'),
#  ({'hi': True,
#    'bam': True,
#    '@barsandmelody': True,
#    'follow': True,
#    'bestfriend': True,
#    '@969horan696': True,
#    'love': True,
#    'lot': True,
#    ':)': True,
#    'see': True,
#    'warsaw': True,
#    '<3': True,
#    'x43': True},
#   'Positive'),
#  ({'@mandascapinello': True,
#    'oh': True,
#    'yeah': True,
#    'definitely': True,
#    'go': True,
#    'try': True,
#    'tonight': True,
#    ':)': True,
#    'take': True,
#    'advice': True,
#    'treviso': True},
#   'Positive'),
#  ({'@morallosanthony': True,
#    'follow': True,
#    '@jnlazts': True,
#    'u': True,
#    'back': True,
#    ':)': True},
#   'Positive'),
#  ({'@nikkieriozzi': True,
#    'hi': True,
#    'would': True,
#    'like': True,
#    '@impastel': True,
#    'concert': True,
#    'let': True,
#    'know': True,
#    'city': True,
#    'country': True,
#    "i'll": True,
#    'start': True,
#    'work': True,
#    'thanks': True,
#    ':)': True},
#   'Positive'),
#  ({'fine': True,
#    '...': True,
#    'gorgeous': True,
#    'friday': True,
#    'friend': True,
#    '..': True,
#    'xo': True,
#    ':)': True},
#   'Positive'),
#  ({'oven': True,
#    'roast': True,
#    'garlic': True,
#    'olive': True,
#    'oil': True,
#    'sun': True,
#    'dry': True,
#    'tomato': True,
#    'dried': True,
#    'basil': True,
#    'century': True,
#    'tuna': True,
#    ':)': True},
#   'Positive'),
#  ({'@hostmyoffice': True,
#    '@nigelpwhittaker': True,
#    '@lemezma': True,
#    '@twbc_business': True,
#    '@_thebunkerjl': True,
#    'right': True,
#    'back': True,
#    'atchya': True,
#    'great': True,
#    'day': True,
#    'everyone': True,
#    ':)': True},
#   'Positive'),
#  ({'@teamtall17': True,
#    '@flashhayer': True,
#    'even': True,
#    'follow': True,
#    'back': True,
#    ':-)': True},
#   'Positive'),
#  ({'future': True, 'almost': True, ':)': True}, 'Positive'),
#  ({'#followfriday': True,
#    '@michelploria': True,
#    '@myfrenchcity': True,
#    '@jasoncreation': True,
#    'top': True,
#    'new': True,
#    'follower': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'chance': True, ':)': True}, 'Positive'),
#  ({'@chiab2486': True,
#    '@mrclivec': True,
#    '@pcdkirkwood': True,
#    '@dc_arvsgt': True,
#    '@cops_president': True,
#    '@emwilliamscccu': True,
#    '@laurargallagher': True,
#    '@hall11kate': True,
#    '@laminx541': True,
#    '@johntarbet71': True,
#    'cheer': True,
#    ':)': True},
#   'Positive'),
#  ({'@thatguycalledp': True,
#    'go': True,
#    'po': True,
#    'ice': True,
#    'cream': True,
#    ':)': True},
#   'Positive'),
#  ({'@19strawberry66': True, 'agree': True, '100': True, ':)': True},
#   'Positive'),
#  ({'@spazzytsukihara': True,
#    'hehehehe': True,
#    'thats': True,
#    'point': True,
#    ':p': True},
#   'Positive'),
#  ({'@kalinwhite': True,
#    'next': True,
#    'time': True,
#    'stay': True,
#    'home': True,
#    ':)': True},
#   'Positive'),
#  ({'@gculloty87': True, 'thanks': True, ':)': True}, 'Positive'),
#  ({'#followfriday': True,
#    '@digitalplace2be': True,
#    '@intlboost': True,
#    '@_lafontpresse': True,
#    'top': True,
#    'support': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'@stayfaboo': True, 'soon': True, 'promise': True, ':)': True}, 'Positive'),
#  ({'web': True,
#    'whatsapp': True,
#    'volta': True,
#    'funcionar': True,
#    'com': True,
#    'iphone': True,
#    'jailbroken': True,
#    ':-)': True},
#   'Positive'),
#  ({'@crustyolddeen': True,
#    'plan': True,
#    'watch': True,
#    'late': True,
#    '34': True,
#    'min': True,
#    'leia': True,
#    'appear': True,
#    'hologram': True,
#    'r2d2': True,
#    'w': True,
#    'message': True,
#    'obi': True,
#    'wan': True,
#    'sit': True,
#    'luke': True,
#    ':)': True},
#   'Positive'),
#  ({'@mburu__': True,
#    'inter': True,
#    '3': True,
#    'ucl': True,
#    'arsenal': True,
#    '...': True,
#    'small': True,
#    'team': True,
#    'right': True,
#    ':)': True},
#   'Positive'),
#  ({'passing': True,
#    ':)': True,
#    '🚂': True,
#    'dewsbury': True,
#    'railway': True,
#    'station': True,
#    'dew': True,
#    '@nationalrailenq': True,
#    'west': True,
#    'yorkshire': True},
#   'Positive'),
#  ({'@clearlyarticle': True, ':)': True, '430': True, 'smh': True}, 'Positive'),
#  ({'@uptommosass': True,
#    '9:25': True,
#    ':)': True,
#    'live': True,
#    'scotland': True,
#    'strange': True,
#    'imagine': True,
#    'megan': True,
#    'xx': True},
#   'Positive'),
#  ({'@bookmyshow': True,
#    '#masaantoday': True,
#    'a4': True,
#    '...': True,
#    'shweta': True,
#    'tripathi': True,
#    ':-)': True,
#    '..': True},
#   'Positive'),
#  ({'@wforwoman': True,
#    '5': True,
#    '20': True,
#    'w': True,
#    'kurta': True,
#    'mom': True,
#    'half': True,
#    'number': True,
#    ':d': True,
#    '#wsalelove': True},
#   'Positive'),
#  ({'ah': True,
#    'hello': True,
#    'back': True,
#    'larry': True,
#    '@transworldbooks': True,
#    ':)': True},
#   'Positive'),
#  ({'anyway': True,
#    'friday': True,
#    'look': True,
#    'kinda': True,
#    'gooood': True,
#    ':)': True},
#   'Positive'),
#  ({'@jhun_hunyo': True,
#    'follow': True,
#    '@jnlazts': True,
#    'u': True,
#    'back': True,
#    ':)': True},
#   'Positive'),
#  ({'lol': True,
#    'well': True,
#    "that's": True,
#    'life': True,
#    ':)': True,
#    'thank': True,
#    'god': True,
#    'enn': True},
#   'Positive'),
#  ({'@ojbj': True,
#    '@holmesjsamuel': True,
#    'surely': True,
#    'could': True,
#    'warmup': True,
#    'morning': True,
#    'coming': True,
#    '15th': True,
#    'bath': True,
#    ':)': True,
#    'xx': True},
#   'Positive'),
#  ({'dum': True,
#    'andar': True,
#    'ram': True,
#    'sampath': True,
#    'sona': True,
#    'mohapatra': True,
#    'samantha': True,
#    'edwards': True,
#    'mein': True,
#    'tulane': True,
#    'razi': True,
#    'wah': True,
#    "that's": True,
#    'josh': True,
#    ':)': True},
#   'Positive'),
#  ({'@justinbieber': True, ':)': True, 'always': True, 'smile': True},
#   'Positive'),
#  ({'@darlakim_': True, 'picture': True, ':)': True}, 'Positive'),
#  ({'@arsenalnewsasit': True,
#    'thanks': True,
#    'time': True,
#    '16.20': True,
#    'right': True,
#    "that's": True,
#    'perfect': True,
#    'timing': True,
#    ':)': True},
#   'Positive'),
#  ({'#followfriday': True,
#    '@izywaylesexpats': True,
#    '@na4innov': True,
#    '@inxpresscoazur': True,
#    'top': True,
#    'engage': True,
#    'member': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'@juleeyaanaa': True, 'know': True, ':)': True}, 'Positive'),
#  ({'#giveitup': True,
#    'already': True,
#    'give': True,
#    'gas': True,
#    'subsidy': True,
#    'long': True,
#    'back': True,
#    'initiative': True,
#    'propose': True,
#    '..': True,
#    'feeling': True,
#    'delight': True,
#    ':)': True},
#   'Positive'),
#  ({'@dayloladay': True, 'miss': True, 'yesterday': True, ':-)': True},
#   'Positive'),
#  ({'hi': True,
#    'bam': True,
#    '@barsandmelody': True,
#    'follow': True,
#    'bestfriend': True,
#    '@969horan696': True,
#    'love': True,
#    'lot': True,
#    ':)': True,
#    'see': True,
#    'warsaw': True,
#    '<3': True,
#    'x42': True},
#   'Positive'),
#  ({'@jaimeemelanie_': True,
#    'lmaoo': True,
#    'best': True,
#    'song': True,
#    'ever': True,
#    '<3': True,
#    'shall': True,
#    'little': True,
#    'throwback': True,
#    'week': True,
#    ':p': True},
#   'Positive'),
#  ({'@clazziebritchas': True,
#    'go': True,
#    'outlying': True,
#    'island': True,
#    'cheung': True,
#    'chau': True,
#    'mui': True,
#    'wo': True,
#    '...': True,
#    'totally': True,
#    'different': True,
#    ':)': True},
#   'Positive'),
#  ({'#kfckitchentours': True,
#    'kitchen': True,
#    'clean': True,
#    "i'm": True,
#    'totally': True,
#    'amaze': True,
#    ':)': True,
#    '@kfc_india': True},
#   'Positive'),
#  ({'@cybelxxx': True,
#    'follow': True,
#    '@jnlazts': True,
#    'u': True,
#    'back': True,
#    ':)': True},
#   'Positive'),
#  ({'cusp': True,
#    'test': True,
#    'water': True,
#    'hope': True,
#    'reward': True,
#    ':)': True},
#   'Positive'),
#  ({'#followfriday': True,
#    '@broadcastbeat': True,
#    '@insunwetrust': True,
#    '@conseilsmkg': True,
#    'top': True,
#    'influencers': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'arummzz': True,
#    "let's": True,
#    'go': True,
#    '...': True,
#    "i'll": True,
#    'drive': True,
#    ':p': True,
#    '#traveling': True,
#    '#traveler': True,
#    '#yogyakarta': True,
#    '#jeep': True,
#    '#indonesia': True,
#    '#instamood': True,
#    '…': True},
#   'Positive'),
#  ({'anyone': True, 'wanna': True, 'skype': True, ':d': True}, 'Positive'),
#  ({'@agylyxa': True,
#    'may': True,
#    'look': True,
#    'bit': True,
#    'real': True,
#    'nice': True,
#    'friendly': True,
#    'girl': True,
#    ':-)': True},
#   'Positive'),
#  ({'im': True, 'like': True, 'pretend': True, ':)': True}, 'Positive'),
#  ({'watch': True, 'concert': True, 'film': True, ':)': True}, 'Positive'),
#  ({'congratulations': True,
#    '@amisharanka95': True,
#    'winner': True,
#    '#cheesydelights': True,
#    'contest': True,
#    ':)': True,
#    'please': True,
#    'dm': True,
#    'us': True,
#    'address': True,
#    'contact': True,
#    'number': True},
#   'Positive'),
#  ({':)': True, 'great': True, 'weekend': True, 'guy': True}, 'Positive'),
#  ({'#followfriday': True,
#    '@clararojasg': True,
#    '@bf_p2c': True,
#    '@mybusiness_plan': True,
#    'top': True,
#    'new': True,
#    'follower': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'@puamagasiva': True,
#    'cool': True,
#    'see': True,
#    'film': True,
#    'today': True,
#    ':)': True},
#   'Positive'),
#  ({'check': True,
#    'email': True,
#    'marketing': True,
#    '24/7': True,
#    'regret': True,
#    'buy': True,
#    ':)': True},
#   'Positive'),
#  ({'@vineshpomal': True,
#    'lol': True,
#    'come': True,
#    'join': True,
#    'us': True,
#    '...': True,
#    'see': True,
#    'u': True,
#    'around': True,
#    '14': True,
#    'hour': True,
#    'leave': True,
#    'without': True,
#    'delay': True,
#    ':)': True},
#   'Positive'),
#  ({'actually': True,
#    'easy': True,
#    'like': True,
#    'must': True,
#    'station': True,
#    'guess': True,
#    'train': True,
#    'wd': True,
#    'take': True,
#    'least': True,
#    'hour': True,
#    'shift': True,
#    'engine': True,
#    'etc': True,
#    ':-)': True},
#   'Positive'),
#  ({'sunburn': True, 'peel': True, ':-)': True}, 'Positive'),
#  ({'@sexdate_gratis': True,
#    'visit': True,
#    'blog': True,
#    'thanks': True,
#    ':d': True},
#   'Positive'),
#  ({'@tikosd': True,
#    'hi': True,
#    'would': True,
#    'like': True,
#    '@impastel': True,
#    'concert': True,
#    'let': True,
#    'know': True,
#    'city': True,
#    'country': True,
#    "i'll": True,
#    'start': True,
#    'work': True,
#    'thanks': True,
#    ':)': True},
#   'Positive'),
#  ({'@no1_razorstan': True, 'talk': True, 'help': True, ':)': True},
#   'Positive'),
#  ({'@cassthetrainer': True,
#    'huge': True,
#    'warm': True,
#    'welcome': True,
#    '@vodkablond': True,
#    ':-)': True,
#    '☆': True,
#    'finally': True,
#    'complete': True,
#    'triangle': True},
#   'Positive'),
#  ({'@luciennediver': True,
#    'live': True,
#    'northern': True,
#    'ireland': True,
#    ':)': True,
#    'sight': True,
#    'see': True},
#   'Positive'),
#  ({'1mica': True,
#    'follow': True,
#    '@jnlazts': True,
#    'u': True,
#    'back': True,
#    ':)': True},
#   'Positive'),
#  ({'#followfriday': True,
#    '@z_intl_agency': True,
#    '@tivipro': True,
#    '@compexly': True,
#    'top': True,
#    'support': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'stats': True,
#    'day': True,
#    'arrive': True,
#    '1': True,
#    'new': True,
#    'follower': True,
#    'unfollowers': True,
#    ':)': True,
#    'via': True},
#   'Positive'),
#  ({'@imraina': True,
#    'feel': True,
#    'smthng': True,
#    'fr': True,
#    'u': True,
#    '...': True,
#    'lol': True,
#    'wanna': True,
#    'hug': True,
#    'xoxo': True,
#    'love': True,
#    'uu': True,
#    'jaann': True,
#    'take': True,
#    'care': True,
#    ':)': True,
#    '<3': True},
#   'Positive'),
#  ({'thanks': True, 'mom': True, ':)': True}, 'Positive'),
#  ({'thanks': True,
#    '#topnewfollowers': True,
#    '@bestofficpad': True,
#    '@mrcfluegel': True,
#    '@jeanmarcpn': True,
#    'happy': True,
#    'connect': True,
#    ':)': True},
#   'Positive'),
#  ({'@mooseallain': True,
#    '@meatbingo': True,
#    'wonderful': True,
#    'thing': True,
#    'make': True,
#    'feel': True,
#    'fluffy': True,
#    'inside': True,
#    'great': True,
#    'pirouette': True,
#    'moose': True,
#    ':d': True},
#   'Positive'),
#  ({'@kristophcajon': True,
#    'trip': True,
#    'philly': True,
#    'december': True,
#    ':)': True,
#    "i'd": True,
#    'love': True,
#    'come': True,
#    'dude': True},
#   'Positive'),
#  ({'hi': True,
#    'bam': True,
#    '@barsandmelody': True,
#    'follow': True,
#    'bestfriend': True,
#    '@969horan696': True,
#    'love': True,
#    'lot': True,
#    ':)': True,
#    'see': True,
#    'warsaw': True,
#    '<3': True,
#    'x41': True},
#   'Positive'),
#  ({'question': True,
#    'flaw': True,
#    'pain': True,
#    'negate': True,
#    'strength': True,
#    ':)': True},
#   'Positive'),
#  ({'@reflectknives': True,
#    'go': True,
#    'solo': True,
#    'move': True,
#    'make': True,
#    ':d': True},
#   'Positive'),
#  ({'hey': True,
#    'fav': True,
#    'nirvana': True,
#    'song': True,
#    'smell': True,
#    'like': True,
#    'teen': True,
#    'spirit': True,
#    'rip': True,
#    'amy': True,
#    'winehouse': True,
#    ':-)': True},
#   'Positive'),
#  ({'#followfriday': True,
#    '@ccidelyon': True,
#    '@cci_95': True,
#    '@cpneri_esigroup': True,
#    'top': True,
#    'engage': True,
#    'member': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({"let's": True,
#    'go': True,
#    '...': True,
#    "i'll": True,
#    'drive': True,
#    ':p': True,
#    '#traveling': True,
#    '#traveler': True,
#    '#yogyakarta': True,
#    '#jeep': True,
#    '#indonesia': True,
#    '#instamood': True,
#    '…': True},
#   'Positive'),
#  ({'name': True,
#    'couple': True,
#    'yet': True,
#    '#tomhiddleston': True,
#    '#elizabetholsen': True,
#    '#yaytheylookgreat': True,
#    ':)': True},
#   'Positive'),
#  ({'love': True,
#    'goodnight': True,
#    'vid': True,
#    'go': True,
#    'wake': True,
#    'one': True,
#    ':)': True},
#   'Positive'),
#  ({'weekend': True,
#    'gonna': True,
#    'shoot': True,
#    'lovely': True,
#    '@narakubrock': True,
#    '<3': True,
#    'picture': True,
#    'make': True,
#    'last': True,
#    'time': True,
#    ':d': True},
#   'Positive'),
#  ({'anyway': True, ':-)': True}, 'Positive'),
#  ({'itty': True, 'bitty': True, 'teenie': True, 'bikini': True, ':)': True},
#   'Positive'),
#  ({'join': True,
#    '#hushedpinwithsammy': True,
#    'event': True,
#    ':d': True,
#    'might': True,
#    'get': True,
#    'text': True,
#    '@sammywilk': True,
#    'day': True,
#    'luv': True,
#    'u': True,
#    '@hushedapp': True},
#   'Positive'),
#  ({'always': True,
#    'much': True,
#    'fun': True,
#    '4th': True,
#    'hour': True,
#    'get': True,
#    'together': True,
#    ':)': True,
#    'ending': True,
#    'night': True,
#    'ice': True,
#    'cream': True,
#    'xfiles': True,
#    'content': True},
#   'Positive'),
#  ({'@aangelayap': True, 'easy': True, ':d': True}, 'Positive'),
#  ({'@nttownend': True,
#    'yes': True,
#    'surprise': True,
#    'see': True,
#    'bit': True,
#    'rain': True,
#    'today': True,
#    '...': True,
#    ':)': True},
#   'Positive'),
#  ({'@reyesfraulein': True,
#    'follow': True,
#    '@jnlazts': True,
#    'u': True,
#    'back': True,
#    ':)': True},
#   'Positive'),
#  ({'@fatpunkstudio': True,
#    'fabulous': True,
#    'friday': True,
#    'keep': True,
#    'fantastic': True,
#    'work': True,
#    ':)': True},
#   'Positive'),
#  ({'@justinbieber': True,
#    'please': True,
#    'follow': True,
#    '9': True,
#    '♡': True,
#    'jb': True,
#    'love': True,
#    'always': True,
#    'forever': True,
#    "i'm": True,
#    'belieber': True,
#    ':)': True,
#    'u': True},
#   'Positive'),
#  ({'#followfriday': True,
#    '@diplomix': True,
#    '@cci_entreprises': True,
#    '@cci_92': True,
#    'top': True,
#    'influencers': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'morning': True, ':)': True}, 'Positive'),
#  ({'@franchiseedsuk': True, 'good': True, 'hear': True, ':)': True},
#   'Positive'),
#  ({'@lusciouslyndee1': True,
#    'nighty': True,
#    'night': True,
#    'let': True,
#    'bed': True,
#    'bug': True,
#    'bite': True,
#    ':d': True},
#   'Positive'),
#  ({'@bonsplansblog': True,
#    'beautiful': True,
#    'bracelet': True,
#    'good': True,
#    'idea': True,
#    ':)': True},
#   'Positive'),
#  ({'@guywilliamsguy': True, 'wait': True, 'foundry': True, ':)': True},
#   'Positive'),
#  ({'@kalinwhite': True, 'like': True, 'game': True, ':)': True}, 'Positive'),
#  ({'@suzannepanter': True,
#    '@kevinbacon': True,
#    '@katosman': True,
#    'ah': True,
#    'make': True,
#    'sense': True,
#    '...': True,
#    'see': True,
#    'pic': True,
#    'eff': True,
#    'phone': True,
#    'last': True,
#    'night': True,
#    'woot': True,
#    ':)': True,
#    'x': True},
#   'Positive'),
#  ({'@derek_gta': True,
#    'hi': True,
#    'derek': True,
#    'could': True,
#    'try': True,
#    'use': True,
#    'parkshare': True,
#    'gloucestershire': True,
#    ':)': True},
#   'Positive'),
#  ({'aaaahhh': True,
#    'man': True,
#    'track': True,
#    'traffic': True,
#    'stress': True,
#    'reliever': True,
#    ':)': True},
#   'Positive'),
#  ({'#followfriday': True,
#    '@elevents2': True,
#    '@joussotfrench_j': True,
#    '@nyibf': True,
#    'top': True,
#    'new': True,
#    'follower': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'@el1new': True, "how're": True, 'today': True, 'dear': True, ':)': True},
#   'Positive'),
#  ({'@jesutomisin': True,
#    'hear': True,
#    'guy': True,
#    'want': True,
#    'arbeloa': True,
#    ':d': True},
#   'Positive'),
#  ({'@shawnmendes': True,
#    'turn': True,
#    '17': True,
#    '15': True,
#    'day': True,
#    '...': True,
#    'omg': True,
#    'least': True,
#    '3': True,
#    'year': True,
#    'difference': True,
#    ':)': True},
#   'Positive'),
#  ({'@matteomeacci': True,
#    'well': True,
#    'say': True,
#    'europe': True,
#    'rise': True,
#    'find': True,
#    'hard': True,
#    'believe': True,
#    ':)': True},
#   'Positive'),
#  ({'@wforwoman': True,
#    '#wsalelove': True,
#    'uncountable': True,
#    'coz': True,
#    'love': True,
#    'unlimited': True,
#    ':)': True},
#   'Positive'),
#  ({'yes': True, 'course': True, ':)': True, '#teampositive': True},
#   'Positive'),
#  ({'yes': True, 'love': True, ':-)': True, '#aldub': True}, 'Positive'),
#  ({'@coffeebreak22': True,
#    '@laurenarren': True,
#    '@drparkave': True,
#    '@jwkanyuira1969': True,
#    '@dheracing': True,
#    '@rhoachri': True,
#    '@barbarabathurst': True,
#    '@1cryingeye': True,
#    '@willisteam': True,
#    ':)': True,
#    '☕': True,
#    'thank': True,
#    'rita': True},
#   'Positive'),
#  ({'@mikerobb': True,
#    'hi': True,
#    'could': True,
#    'please': True,
#    'dm': True,
#    'us': True,
#    'info': True,
#    "we'd": True,
#    'happy': True,
#    'help': True,
#    ':)': True},
#   'Positive'),
#  ({'@24gooch': True, 'way': True, 'boy': True, ':)': True}, 'Positive'),
#  ({'@graphure': True,
#    'hope': True,
#    'get': True,
#    'lot': True,
#    'nice': True,
#    'gift': True,
#    ':d': True},
#   'Positive'),
#  ({'hi': True,
#    'bam': True,
#    '@barsandmelody': True,
#    'follow': True,
#    'bestfriend': True,
#    '@969horan696': True,
#    'love': True,
#    'lot': True,
#    ':)': True,
#    'see': True,
#    'warsaw': True,
#    '<3': True,
#    'x40': True},
#   'Positive'),
#  ({'#followfriday': True,
#    '@acbm_secem': True,
#    '@dcarsoncpa_nyc': True,
#    '@promosalonsinfo': True,
#    'top': True,
#    'support': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'true': True, ':)': True}, 'Positive'),
#  ({'add': True,
#    'video': True,
#    '@youtube': True,
#    'playlist': True,
#    'im': True,
#    'back': True,
#    'twitch': True,
#    'today': True,
#    'go': True,
#    'league': True,
#    ':)': True,
#    '1': True,
#    '3': True},
#   'Positive'),
#  ({'@zarlashtfaisal': True,
#    '@tabinda_samar': True,
#    'sethi': True,
#    'high': True,
#    ':)': True},
#   'Positive'),
#  ({'@iam_lennox': True, 'exe': True, 'skeem': True, 'saam': True, ':)': True},
#   'Positive'),
#  ({'people': True,
#    'make': True,
#    'smile': True,
#    ':)': True,
#    '@_pumpchkin_': True,
#    '@aka_pump': True,
#    '@lilfrenchmsp': True,
#    '8_': True},
#   'Positive'),
#  ({'@coschedule': True, 'thanks': True, 'invite': True, ':)': True},
#   'Positive'),
#  ({'@syedihusain': True,
#    'polite': True,
#    'izzat': True,
#    ':)': True,
#    'wese': True,
#    'trust': True,
#    'khawateen': True,
#    'k': True,
#    'sath': True,
#    'selfies': True,
#    'say': True,
#    'mana': True,
#    'kar': True,
#    'deya': True},
#   'Positive'),
#  ({'thank': True,
#    '@movietubepw': True,
#    "that's": True,
#    'friday': True,
#    'evening': True,
#    'sort': True,
#    ':-)': True},
#   'Positive'),
#  ({'@nova_caneeee': True, 'smart': True, ':)': True}, 'Positive'),
#  ({'@vaalthepal': True, ':-)': True, 'nice': True, 'hair': True, 'tbh': True},
#   'Positive'),
#  ({'5': True, 'year': True, ':)': True}, 'Positive'),
#  ({'jacob': True, 'g': True, 'upgrade': True, ':-)': True}, 'Positive'),
#  ({'@heydonworks': True, 'nice': True, 'tee': True, 'man': True, ':)': True},
#   'Positive'),
#  ({'happy': True,
#    'family': True,
#    'vacation': True,
#    '..': True,
#    ':d': True,
#    'pic': True,
#    '—': True},
#   'Positive'),
#  ({'sleep': True, 'would': True, 'nice': True, ':-)': True}, 'Positive'),
#  ({'reading': True, 'beautiful': True, 'like': True, 'read': True, ':)': True},
#   'Positive'),
#  ({'talking': True,
#    'one': True,
#    'person': True,
#    '...': True,
#    'two': True,
#    'conversations': True,
#    ':)': True},
#   'Positive'),
#  ({'skype': True, 'fun': True, ':-)': True}, 'Positive'),
#  ({'@soggystones': True, 'online': True, ':)': True}, 'Positive'),
#  ({'...': True, 'friday': True, ':d': True}, 'Positive'),
#  ({'#followfriday': True,
#    '@ccifccanada': True,
#    '@adamevnmnt': True,
#    '@boxcalf1': True,
#    'top': True,
#    'engage': True,
#    'member': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'something': True,
#    'get': True,
#    '#friday': True,
#    'great': True,
#    'start': True,
#    ':)': True,
#    'day': True,
#    '#mclaren': True,
#    '#fridayfeeling': True,
#    '#tgif': True},
#   'Positive'),
#  ({'@avinpera': True,
#    'follow': True,
#    '@jnlazts': True,
#    'u': True,
#    'back': True,
#    ':)': True},
#   'Positive'),
#  ({'square': True,
#    'enix': True,
#    'bissmillah': True,
#    'ya': True,
#    'allah': True,
#    ':)': True},
#   'Positive'),
#  ({'@sephtonmark': True,
#    "we're": True,
#    'training': True,
#    '#socent': True,
#    'startup': True,
#    '@tobaccodocklon': True,
#    'week': True,
#    'w': True,
#    '@helpingb': True,
#    "we'd": True,
#    'love': True,
#    'drop': True,
#    'youre': True,
#    'arnd': True,
#    'town': True,
#    ':)': True},
#   'Positive'),
#  ({'@hgvwolfie': True,
#    'basically': True,
#    'piss': True,
#    'cup': True,
#    'test': True,
#    ':)': True},
#   'Positive'),
#  ({'@ellenrstewart': True, 'next': True, ':)': True}, 'Positive'),
#  ({'@ionswitz': True,
#    '@notch': True,
#    'also': True,
#    'twitter': True,
#    'terrible': True,
#    'complicated': True,
#    'discussion': True,
#    ':)': True},
#   'Positive'),
#  ({'snapchat': True,
#    'lynettelowe': True,
#    '#snapchat': True,
#    '#kikmenow': True,
#    '#snapme': True,
#    '#hot': True,
#    '#amazon': True,
#    '#kikmeguys': True,
#    ':)': True},
#   'Positive'),
#  ({'look': True,
#    'forward': True,
#    '12': True,
#    'hour': True,
#    'shift': True,
#    'today': True,
#    ':)': True},
#   'Positive'),
#  ({'@ely83_ely': True,
#    'definately': True,
#    'agree': True,
#    'grow': True,
#    'sport': True,
#    'drop': True,
#    'email': True,
#    'detail': True,
#    'see': True,
#    ':-)': True},
#   'Positive'),
#  ({'last': True, 'rt': True, ':)': True}, 'Positive'),
#  ({'...': True,
#    'rakyat': True,
#    'keep': True,
#    'visit': True,
#    'blog': True,
#    'read': True,
#    'write': True,
#    ':)': True},
#   'Positive'),
#  ({'ever': True,
#    'since': True,
#    'mention': True,
#    'fly': True,
#    'fish': True,
#    'day': True,
#    "i'm": True,
#    'get': True,
#    'follow': True,
#    'promoted': True,
#    'post': True,
#    'lol': True,
#    'cyber': True,
#    'stalk': True,
#    ':-)': True},
#   'Positive'),
#  ({'@gurmeetramrahim': True,
#    '#ourdaughtersourpride': True,
#    '#mypapamypride': True,
#    'proud': True,
#    'papa': True,
#    'coach': True,
#    ':)': True},
#   'Positive'),
#  ({'@imarpita': True, 'great': True, 'talk': True, ':d': True}, 'Positive'),
#  ({'11': True,
#    'never': True,
#    'see': True,
#    'positive': True,
#    'kha': True,
#    'u': True,
#    'could': True,
#    'also': True,
#    'mention': True,
#    'atleast': True,
#    'go': True,
#    ':)': True},
#   'Positive'),
#  ({'hi': True,
#    'bam': True,
#    '@barsandmelody': True,
#    'follow': True,
#    'bestfriend': True,
#    '@969horan696': True,
#    'love': True,
#    'lot': True,
#    ':)': True,
#    'see': True,
#    'warsaw': True,
#    '<3': True,
#    'x39': True},
#   'Positive'),
#  ({'@_pigglywiggly': True,
#    '@omundson': True,
#    'mango': True,
#    "lassi's": True,
#    "monty's": True,
#    'marvellous': True,
#    ':d': True,
#    'though': True,
#    'suspect': True,
#    "that's": True,
#    'mean': True,
#    '...': True},
#   'Positive'),
#  ({'#followfriday': True,
#    '@stayfanchemin': True,
#    '@cci_75': True,
#    '@aandreup': True,
#    'top': True,
#    'influencers': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'@thakurain_': True,
#    'haha': True,
#    'yes': True,
#    '24': True,
#    'hr': True,
#    'time': True,
#    'come': True,
#    'touch': True,
#    'kepler': True,
#    '452b': True,
#    'chalna': True,
#    'hai': True,
#    ':d': True},
#   'Positive'),
#  ({'@iyah_mohamad': True,
#    'follow': True,
#    '@jnlazts': True,
#    'u': True,
#    'back': True,
#    ':)': True},
#   'Positive'),
#  ({'@allygrrdo': True, 'thankyou': True, 'pretty': True, ':)': True},
#   'Positive'),
#  ({'@pinkpeoniesblog': True,
#    '@helloprettysa': True,
#    'definitely': True,
#    'hazel': True,
#    'food': True,
#    'market': True,
#    'brooklyn': True,
#    'pta': True,
#    ':)': True},
#   'Positive'),
#  ({'still': True, 'awake': True, ':)': True}, 'Positive'),
#  ({'@joiredve': True, 'okayy': True, ':d': True}, 'Positive'),
#  ({'awww': True, 'thank': True, ':)': True}, 'Positive'),
#  ({'@ar1961': True,
#    'ha': True,
#    'surprise': True,
#    'least': True,
#    'okay': True,
#    'see': True,
#    'doc': True,
#    'afternoon': True,
#    'yorkshire': True,
#    'splendid': True,
#    'though': True,
#    ':)': True,
#    'xx': True},
#   'Positive'),
#  ({'@jrturnerphoto': True,
#    '@davidqueenan': True,
#    '@jameslturnbull': True,
#    'spam': True,
#    'folder': True,
#    'wow': True,
#    'win': True,
#    'huge': True,
#    'amount': True,
#    'need': True,
#    'travel': True,
#    'nigeria': True,
#    'claim': True,
#    ':)': True},
#   'Positive'),
#  ({'@perksofnialljh': True,
#    'rted': True,
#    'good': True,
#    'luck': True,
#    ':)': True},
#   'Positive'),
#  ({'legs': True, 'hurt': True, 'bad': True, ':)': True}, 'Positive'),
#  ({'@johnny_lopez96': True,
#    'get': True,
#    'mine': True,
#    'saturday': True,
#    ':-)': True},
#   'Positive'),
#  ({'@imafaithreyes': True,
#    'thaaanks': True,
#    'december': True,
#    'puhon': True,
#    ':)': True},
#   'Positive'),
#  ({'happiness': True, ':)': True}, 'Positive'),
#  ({'@vaibhavvj78': True,
#    '@payumoney': True,
#    'true': True,
#    'change': True,
#    'tnc': True,
#    'without': True,
#    'prior': True,
#    'notification': True,
#    'could': True,
#    'use': True,
#    'last': True,
#    'night': True,
#    ':-)': True},
#   'Positive'),
#  ({'probably': True, 'find': True, 'funny': True, '2:22': True, ':-)': True},
#   'Positive'),
#  ({'@aliyaskates': True,
#    '@yoshihikomkm': True,
#    'fat': True,
#    'co': True,
#    'probably': True,
#    'eat': True,
#    'yuna': True,
#    ':d': True},
#   'Positive'),
#  ({'@emmajaneparsons': True,
#    '@curiousmindsnw': True,
#    'fun': True,
#    'tameside': True,
#    ':)': True},
#   'Positive'),
#  ({'@hydrcted': True, ':-)': True}, 'Positive'),
#  ({'@charmingjedward': True, '´': True, 'welcome': True, ':)': True},
#   'Positive'),
#  ({'google': True, 'account': True, ':)': True}, 'Positive'),
#  ({'@2shymc': True,
#    'call': True,
#    'scouser': True,
#    'everything': True,
#    'hope': True,
#    'zoe': True,
#    'well': True,
#    'mate': True,
#    ':)': True},
#   'Positive'),
#  ({'@rachelevans_28': True,
#    'right': True,
#    'literally': True,
#    'like': True,
#    'maybe': True,
#    'u': True,
#    'get': True,
#    'people': True,
#    'actually': True,
#    'know': True,
#    "they're": True,
#    ':-)': True,
#    '@studenttrip': True},
#   'Positive'),
#  ({'sameee': True, 'rest': True, 'well': True, ':)': True}, 'Positive'),
#  ({'@edgarslame': True,
#    'happy': True,
#    'birthday': True,
#    'edgar': True,
#    'hope': True,
#    'good': True,
#    'one': True,
#    'keep': True,
#    'update': True,
#    'travel': True,
#    'log': True,
#    ':)': True},
#   'Positive'),
#  ({'hello': True, ':d': True, '@vikkfollows': True, '@vikkstar123': True},
#   'Positive'),
#  ({'@marreyjewana': True, 'bring': True, 'abes': True, ':)': True},
#   'Positive'),
#  ({'stats': True,
#    'day': True,
#    'arrive': True,
#    '2': True,
#    'new': True,
# ...
#  ({'lovely': True, 'coffee': True, ':)': True, '@coffeestogo1': True},
#   'Positive'),
#  ({"here's": True,
#    'cute': True,
#    'panda': True,
#    'make': True,
#    'day': True,
#    ':)': True},
#   'Positive'),
#  ({'lovestephi': True, 'thank': True, 'eonnie': True, ':)': True}, 'Positive'),
#  ({'@stokebrisbane': True,
#    'hi': True,
#    'saw': True,
#    'u': True,
#    'follow': True,
#    'think': True,
#    'might': True,
#    'like': True,
#    'dark': True,
#    'plz': True,
#    'let': True,
#    'us': True,
#    'know': True,
#    ':)': True},
#   'Positive'),
#  ({'@polished_teeth': True,
#    'favourite': True,
#    ':)': True,
#    '@ciatelondon': True,
#    'cream': True,
#    'soda': True},
#   'Positive'),
#  ({'love': True,
#    'body': True,
#    'fuller': True,
#    'shit': True,
#    'even': True,
#    'lol': True,
#    "i'm": True,
#    'happy': True,
#    'healthy': True,
#    ':)': True,
#    '..': True,
#    '💓': True},
#   'Positive'),
#  ({'rettweet': True, ':-)': True}, 'Positive'),
#  ({'@dianaaortizz': True,
#    'real': True,
#    'mvg': True,
#    'valuable': True,
#    'girlfriend': True,
#    'stay': True,
#    'till': True,
#    'madrid': True,
#    'game': True,
#    'start': True,
#    ':-)': True},
#   'Positive'),
#  ({'@olx_ohayoung96': True, 'sore': True, 'ya': True, ':)': True}, 'Positive'),
#  ({'@tmhcuddly': True,
#    "i'm": True,
#    'excited': True,
#    'definitely': True,
#    'meet': True,
#    ':)': True},
#   'Positive'),
#  ({'@morriskid': True,
#    'come': True,
#    'bergerac': True,
#    'first': True,
#    'team': True,
#    'leave': True,
#    'u21': True,
#    "i'd": True,
#    'know': True,
#    '#checking': True,
#    'chant': True,
#    ':-)': True},
#   'Positive'),
#  ({'@rizwanism': True,
#    ':)': True,
#    'choice': True,
#    'food': True,
#    'left': True,
#    'individual': True},
#   'Positive'),
#  ({'@vickicartagena': True,
#    'episode': True,
#    'excellent': True,
#    'far': True,
#    ':-)': True,
#    'love': True,
#    'adam': True,
#    "beach's": True,
#    'movie': True,
#    'show': True,
#    "i'm": True,
#    'look': True,
#    'forward': True,
#    'see': True,
#    'suicide': True,
#    'squad': True,
#    'next': True,
#    'year': True},
#   'Positive'),
#  ({'growing': True,
#    'fond': True,
#    'christopher': True,
#    'like': True,
#    'initially': True,
#    'cocky': True,
#    'really': True,
#    'prove': True,
#    "attitude's": True,
#    'improve': True,
#    ':d': True},
#   'Positive'),
#  ({'@glenocsko': True,
#    'sound': True,
#    'good': True,
#    'dm': True,
#    'email': True,
#    'address': True,
#    'suggest': True,
#    'date': True,
#    'coffee': True,
#    ':)': True},
#   'Positive'),
#  ({'@forlodge1': True,
#    'indeed': True,
#    'many': True,
#    'thanks': True,
#    ':-)': True},
#   'Positive'),
#  ({'smile': True, 'even': True, 'pain': True, ':)': True}, 'Positive'),
#  ({'hi': True, 'happys': True, ':)': True}, 'Positive'),
#  ({'funny': True,
#    'intelligent': True,
#    'strong': True,
#    '...': True,
#    ':-)': True},
#   'Positive'),
#  ({'hello': True,
#    ':)': True,
#    'get': True,
#    'youth': True,
#    'job': True,
#    'opportunities': True,
#    'follow': True,
#    '@tolajobjobs': True,
#    '@me1campbell': True},
#   'Positive'),
#  ({'@mokwepa': True, 'use': True, 'cs': True, ':)': True}, 'Positive'),
#  ({'ever': True,
#    'watch': True,
#    'certain': True,
#    "people's": True,
#    'snapchat': True,
#    'bc': True,
#    'know': True,
#    ':-)': True},
#   'Positive'),
#  ({'@ibnnabih1': True,
#    "that's": True,
#    'ok': True,
#    'know': True,
#    'busy': True,
#    ':)': True},
#   'Positive'),
#  ({'last': True, '2': True, 'exam': True, ':)': True}, 'Positive'),
#  ({'forgot': True, 'u': True, ':)': True}, 'Positive'),
#  ({'fun': True,
#    'fact': True,
#    'love': True,
#    'meet': True,
#    'new': True,
#    'people': True,
#    ':)': True},
#   'Positive'),
#  ({'@jaseygalore': True,
#    'know': True,
#    'home-based': True,
#    'office': True,
#    'busy': True,
#    'feel': True,
#    ':-)': True,
#    'pity': True,
#    'knee': True,
#    'happen': True},
#   'Positive'),
#  ({'sale': True,
#    'fleur': True,
#    'dress': True,
#    'cream': True,
#    '#readystock_hijabmart': True,
#    'idr': True,
#    '325.000': True,
#    '200.000': True,
#    ':)': True},
#   'Positive'),
#  ({'14': True, 'thankyou': True, ':)': True}, 'Positive'),
#  ({'@fernandeznoemi4': True,
#    'follow': True,
#    '@jnlazts': True,
#    'u': True,
#    'back': True,
#    ':)': True},
#   'Positive'),
#  ({'tompolo': True,
#    'meeting': True,
#    'aim': True,
#    'stop': True,
#    'sale': True,
#    'oil': True,
#    'cannot': True,
#    'find': True,
#    'buyer': True,
#    ':d': True},
#   'Positive'),
#  ({'@centerfxld': True,
#    "that's": True,
#    'true': True,
#    '@johngreen': True,
#    'disappoint': True,
#    'looking': True,
#    'forward': True,
#    'paper': True,
#    'towns': True,
#    ':)': True},
#   'Positive'),
#  ({"that's": True,
#    'need': True,
#    'know': True,
#    'everything': True,
#    'go': True,
#    'okay': True,
#    ':-)': True},
#   'Positive'),
#  ({'@ltbeautyblog': True,
#    '@fdncoffee': True,
#    'say': True,
#    'less': True,
#    'slacking': True,
#    'get': True,
#    'crack': True,
#    ':)': True},
#   'Positive'),
#  ({'@juliewestern': True,
#    'know': True,
#    'name': True,
#    'particularly': True,
#    'striking': True,
#    'happy': True,
#    'day': True,
#    ':)': True},
#   'Positive'),
#  ({'@misshollylou': True,
#    'hey': True,
#    "here's": True,
#    'invite': True,
#    'join': True,
#    'scope': True,
#    'influencer': True,
#    ':)': True},
#   'Positive'),
#  ({'@deewaniveronica': True, '31': True, 'bad': True, 'mam': True, ':p': True},
#   'Positive'),
#  ({'@francesbeeton': True,
#    'lovely': True,
#    'look': True,
#    'cake': True,
#    'bet': True,
#    'taste': True,
#    'good': True,
#    ':-)': True},
#   'Positive'),
#  ({'feytyaz': True, 'follback': True, 'ya': True, ':)': True}, 'Positive'),
#  ({'@dalenaha1': True,
#    'find': True,
#    'last': True,
#    'night': True,
#    'let': True,
#    'say': True,
#    'instant': True,
#    'stiffening': True,
#    'interest': True,
#    ':)': True},
#   'Positive'),
#  ({'rettweet': True, ':-)': True}, 'Positive'),
#  ({'@chubanhes': True, 'fback': True, ':)': True}, 'Positive'),
#  ({'rettweet': True, ':-)': True}, 'Positive'),
#  ({'ricky_febs': True, 'follback': True, 'ya': True, ':)': True}, 'Positive'),
#  ({'got': True,
#    'secrets': True,
#    'grindea': True,
#    'courier': True,
#    'crypts': True,
#    'possibly': True,
#    'arma': True,
#    '3': True,
#    'record': True,
#    'today': True,
#    '...': True,
#    'gosh': True,
#    'new': True,
#    'game': True,
#    'look': True,
#    'like': True,
#    'limbo': True,
#    ':)': True},
#   'Positive'),
#  ({'@siaramelatienza': True,
#    'follow': True,
#    '@jnlazts': True,
#    'u': True,
#    'back': True,
#    ':)': True},
#   'Positive'),
#  ({'@myriadphoto': True,
#    'thanks': True,
#    'retweeting': True,
#    '@madsenjewellery': True,
#    'orchard': True,
#    'art': True,
#    'show': True,
#    'super': True,
#    'weekend': True,
#    ':)': True},
#   'Positive'),
#  ({'karachi': True,
#    'ka': True,
#    'venice': True,
#    'rain': True,
#    ':)': True,
#    '@rizz_javaid': True,
#    '“': True,
#    '@jaagalerts': True,
#    'several': True,
#    'part': True,
#    'witness': True,
#    'accumulate': True,
#    'water': True,
#    '”': True},
#   'Positive'),
#  ({'maroon': True,
#    'cocktail': True,
#    'dress': True,
#    '#mididresses': True,
#    '@filipinaniah': True,
#    ':)': True},
#   'Positive'),
#  ({'@iampatmae_': True, 'fback': True, 'po': True, ':)': True}, 'Positive'),
#  ({'0-100': True, 'real': True, 'quick': True, ':)': True}, 'Positive'),
#  ({'@iron_vein': True,
#    'morning': True,
#    'mine': True,
#    '1100d': True,
#    'usually': True,
#    'auto-focus': True,
#    'use': True,
#    'manual': True,
#    'really': True,
#    'close': True,
#    'like': True,
#    'shoot': True,
#    'vein': True,
#    'crackle': True,
#    'glaze': True,
#    ':)': True},
#   'Positive'),
#  ({'new': True,
#    'layout': True,
#    'look': True,
#    'bomb': True,
#    ':-)': True,
#    'g': True},
#   'Positive'),
#  ({'thanks': True,
#    'connect': True,
#    '@garrowlscq': True,
#    'hope': True,
#    'great': True,
#    'day': True,
#    'social': True,
#    'website': True,
#    'question': True,
#    'ask': True,
#    ':-)': True},
#   'Positive'),
#  ({'@tweetnesian': True, 'pake': True, ':)': True}, 'Positive'),
#  ({'@gabrielaliuw': True,
#    'hi': True,
#    'make': True,
#    'change': True,
#    'design': True,
#    'hope': True,
#    'like': True,
#    ':)': True},
#   'Positive'),
#  ({'joim': True,
#    'fee': True,
#    'troop': True,
#    ':)': True,
#    'via': True,
#    '@audioboom': True},
#   'Positive'),
#  ({'brand': True,
#    'want': True,
#    'review': True,
#    'beauty': True,
#    'product': True,
#    'blog': True,
#    'mail': True,
#    'ladolcevitainluxembourg@hotmail.com': True,
#    '#prrequest': True,
#    '#journorequest': True,
#    ':)': True},
#   'Positive'),
#  ({'the_madstork': True, 'follback': True, 'ya': True, ':)': True},
#   'Positive'),
#  ({'@ssalchli': True, 'good': True, 'luck': True, 'shaun': True, ':)': True},
#   'Positive'),
#  ({'@madziucha_5': True, 'yes': True, ':)': True}, 'Positive'),
#  ({'anyone': True,
#    'want': True,
#    'add': True,
#    'bot': True,
#    'dm': True,
#    ':)': True,
#    '#bot': True},
#   'Positive'),
#  ({'@chloegmoretz': True,
#    'chloe': True,
#    'watch': True,
#    'let': True,
#    'yesterday': True,
#    'really': True,
#    'awesome': True,
#    'talented': True,
#    'intelligent': True,
#    'actress': True,
#    'beautiful': True,
#    ':)': True},
#   'Positive'),
#  ({'@hesfallenangel': True,
#    'could': True,
#    'get': True,
#    'free': True,
#    'solo': True,
#    'dm': True,
#    'give': True,
#    'away': True,
#    ':)': True,
#    'xoxo': True},
#   'Positive'),
#  ({'@tripverse': True,
#    '@outboundapp': True,
#    'thanks': True,
#    'share': True,
#    'wishing': True,
#    'wicked': True,
#    'weekend': True,
#    ':)': True},
#   'Positive'),
#  ({'hola': True,
#    'juan': True,
#    '..': True,
#    'sending': True,
#    'big': True,
#    'hi': True,
#    'houston': True,
#    'tx': True,
#    ':)': True,
#    "i've": True,
#    'fan': True,
#    'jenni': True,
#    'family': True,
#    "year's": True,
#    'stumble': True,
#    'upon': True,
#    'video': True},
#   'Positive'),
#  ({'@padaleckbye': True,
#    'prob.nice': True,
#    'choker': True,
#    'btw': True,
#    ':)': True},
#   'Positive'),
#  ({'@seoulsjin': True,
#    '@seouljins': True,
#    'seouljins': True,
#    ':)': True,
#    'fine': True,
#    'tbh': True},
#   'Positive'),
#  ({'photoset': True,
#    'sadomasochistsparadise': True,
#    'wynter': True,
#    'bottoms': True,
#    'outtake': True,
#    ':)': True,
#    'sadomasochist': True,
#    '’': True,
#    'paradise': True,
#    'cuties': True},
#   'Positive'),
#  ({'make': True, 'day': True, 'smile': True, ':)': True}, 'Positive'),
#  ({'@ghostkidluke': True, 'fback': True, ':)': True}, 'Positive'),
#  ({'@itsrebeccarayne': True, ':d': True, 'ty': True, 'bby': True}, 'Positive'),
#  ({'please': True,
#    'enjoy': True,
#    'clip': True,
#    'lose': True,
#    'shit': True,
#    'cypher': True,
#    ':)': True},
#   'Positive'),
#  ({'@athrawestokio': True,
#    '@adeccowaytowork': True,
#    '@adeccojapan': True,
#    'next': True,
#    'week': True,
#    'office': True,
#    'let': True,
#    'go': True,
#    ':)': True},
#   'Positive'),
#  ({'@danielcwest': True, 'thank': True, 'follow': True, ':d': True},
#   'Positive'),
#  ({'stats': True,
#    'day': True,
#    'arrive': True,
#    '2': True,
#    'new': True,
#    'follower': True,
#    'unfollowers': True,
#    ':)': True,
#    'via': True},
#   'Positive'),
#  ({'@purehaire': True, 'amen': True, 'thanks': True, ':)': True}, 'Positive'),
#  ({'hi': True,
#    'bam': True,
#    '@barsandmelody': True,
#    'follow': True,
#    'bestfriend': True,
#    '@969horan696': True,
#    'love': True,
#    'lot': True,
#    ':)': True,
#    'see': True,
#    'warsaw': True,
#    '<3': True,
#    'x32': True},
#   'Positive'),
#  ({'@shyayen': True,
#    'follow': True,
#    '@jnlazts': True,
#    'u': True,
#    'back': True,
#    ':)': True},
#   'Positive'),
#  ({'@drenchinwine': True,
#    '@2fai': True,
#    '@chompu_kusuma': True,
#    'paper': True,
#    'girl': True,
#    ':d': True},
#   'Positive'),
#  ({'@gculloty87': True,
#    'know': True,
#    'would': True,
#    'lovely': True,
#    'pic': True,
#    ':)': True,
#    'x': True},
#   'Positive'),
#  ({'@adnancad': True,
#    'planted': True,
#    'people': True,
#    'allow': True,
#    'thing': True,
#    'every': True,
#    ':p': True},
#   'Positive'),
#  ({'@mrporter7': True,
#    'corner': True,
#    'fucking': True,
#    'dope': True,
#    'getting': True,
#    'addict': True,
#    '..': True,
#    'great': True,
#    'job': True,
#    ':d': True},
#   'Positive'),
#  ({'bby': True, 'gurl': True, ':)': True}, 'Positive'),
#  ({'hey': True, ':d': True}, 'Positive'),
#  ({'@nickthebullsfan': True,
#    '@cashnastygaming': True,
#    'still': True,
#    'suck': True,
#    'edit': True,
#    'turn': True,
#    'something': True,
#    'special': True,
#    'owe': True,
#    'guy': True,
#    ':)': True},
#   'Positive'),
#  ({'@ayokejkt': True, 'visit': True, 'blog': True, 'thanks': True, ':d': True},
#   'Positive'),
#  ({'@daannymoncada': True,
#    '@breannelaflare': True,
#    'ugly': True,
#    'daniel': True,
#    'good': True,
#    'ape': True,
#    ':)': True},
#   'Positive'),
#  ({'happy': True,
#    'bday': True,
#    '@cinemainmygenes': True,
#    'saar': True,
#    '...': True,
#    'great': True,
#    'year': True,
#    'ahead': True,
#    ':)': True},
#   'Positive'),
#  ({'@lucylu_xx': True,
#    'thought': True,
#    'might': True,
#    'saw': True,
#    'love': True,
#    'verse': True,
#    'butterfly': True,
#    'part': True,
#    'bonus': True,
#    ':)': True},
#   'Positive'),
#  ({'thank': True,
#    ':-)': True,
#    'ok': True,
#    'fun': True,
#    '@anvy2446': True,
#    '@4humanitees': True,
#    '@sexyaf12': True,
#    '@kikbella': True,
#    '@adasamper': True,
#    '@rachellfilsoof': True,
#    'enjoy': True,
#    'day': True,
#    'u': True},
#   'Positive'),
#  ({'well': True, 'good': True, 'morning': True, ':d': True}, 'Positive'),
#  ({'@palakspatel': True, 'would': True, 'follow': True, ':)': True},
#   'Positive'),
#  ({'busy': True,
#    'productive': True,
#    'day': True,
#    'fill': True,
#    'tear': True,
#    'hour': True,
#    'laughter': True,
#    'today': True,
#    'good': True,
#    ':)': True},
#   'Positive'),
#  ({'@17bljpk': True,
#    'hi': True,
#    '5sos': True,
#    'ticket': True,
#    'dm': True,
#    ':)': True},
#   'Positive'),
#  ({'yummmyyy': True,
#    '...': True,
#    ':-)': True,
#    '—': True,
#    'eat': True,
#    'dosa': True},
#   'Positive'),
#  ({'@bbcdoctorwho': True, ':d': True}, 'Positive'),
#  ({'@meglovesgames': True,
#    'probably': True,
#    'easy': True,
#    'meet': True,
#    'station': True,
#    'unless': True,
#    'particularly': True,
#    'want': True,
#    'show': True,
#    'house': True,
#    ':)': True},
#   'Positive'),
#  ({'huge': True,
#    'warm': True,
#    'welcome': True,
#    '@vodkablond': True,
#    ':-)': True},
#   'Positive'),
#  ({'achi': True,
#    'im': True,
#    'busy': True,
#    'next': True,
#    'week': True,
#    'exam': True,
#    'hope': True,
#    'understand': True,
#    'cant': True,
#    'tweet': True,
#    'youuu': True,
#    'bawi': True,
#    'ako': True,
#    'queenesther': True,
#    ':)': True,
#    '@esthercarodan': True},
#   'Positive'),
#  ({'@leemckenzietv': True, 'looking': True, 'sharp': True, ':-)': True},
#   'Positive'),
#  ({'@xwinnermino': True,
#    'yes': True,
#    'im': True,
#    '1': True,
#    'year': True,
#    'young': True,
#    'u': True,
#    ':-)': True,
#    'wonder': True,
#    'youre': True,
#    'huge': True,
#    'boy': True},
#   'Positive'),
#  ({"i'm": True, 'play': True, 'brain': True, 'dots': True, '#braindots': True},
#   'Positive'),
#  ({'ha': True, 'one': True, 'picture': True, ':-)': True}, 'Positive'),
#  ({'@galatasaray': True,
#    'ready': True,
#    ':)': True,
#    '#poldi': True,
#    '#cimbom': True},
#   'Positive'),
#  ({'@luvsocial_media': True, 'thanks': True, 'share': True, ':)': True},
#   'Positive'),
#  ({'@lostchillhoran': True, 'fback': True, ':)': True}, 'Positive'),
#  ({'follow': True, '@jnlazts': True, 'u': True, 'back': True, ':)': True},
#   'Positive'),
#  ({'@graphure': True,
#    'happy': True,
#    'birthday': True,
#    'buddy': True,
#    ':d': True},
#   'Positive'),
#  ({'@waterrat77': True, 'thank': True, ':-)': True}, 'Positive'),
#  ({'sigh': True,
#    '@whykaysbeauty': True,
#    'bruhhh': True,
#    '“': True,
#    '@dopjones': True,
#    'call': True,
#    'daddy': True,
#    'one': True,
#    'time': True,
#    ':)': True,
#    '”': True},
#   'Positive'),
#  ...]

# %%
random.shuffle(dataset)

# %%
dataset
# Out:
# [({'@comicbookhes': True,
#    'course': True,
#    'would': True,
#    'like': True,
#    ':)': True,
#    'x': True},
#   'Positive'),
#  ({'♛': True,
#    '》': True,
#    'love': True,
#    'much': True,
#    'beli̇eve': True,
#    'wi̇ll': True,
#    'follow': True,
#    'please': True,
#    'justi̇n': True,
#    '@justinbieber': True,
#    ':(': True,
#    'x15': True,
#    '339': True,
#    'ｓｅｅ': True,
#    'ｍｅ': True},
#   'Negative'),
#  ({'#ff': True,
#    '#happyfriday': True,
#    '@sagevatic': True,
#    '@marchicristian': True,
#    '@bounceroriginal': True,
#    '@beenfingered': True,
#    '@dj_mando_off': True,
#    'great': True,
#    '#friday': True,
#    ':-)': True},
#   'Positive'),
#  ({'achieving': True,
#    'excellence': True,
#    'music': True,
#    'producer': True,
#    'mind': True,
#    'boggling': True,
#    'fatiguing': True,
#    'job': True,
#    '...': True,
#    'baareeq': True,
#    ':)': True},
#   'Positive'),
#  ({'@karinatuano': True,
#    'shiiiit': True,
#    'kamiss': True,
#    'beh': True,
#    '😭': True,
#    'thank': True,
#    'bby': True,
#    'miss': True,
#    ':(': True,
#    'love': True,
#    'mwa': True},
#   'Negative'),
#  ({'english': True, 'weather': True, 'need': True, 'fix': True, ':(': True},
#   'Negative'),
#  ({'aw': True,
#    'fuck': True,
#    "there's": True,
#    'dress': True,
#    'bag': True,
#    'floor': True,
#    'dammit': True,
#    "that's": True,
#    'really': True,
#    'loud': True,
#    ':(': True},
#   'Negative'),
#  ({'@arsenalnewsasit': True,
#    ':)': True,
#    'thanks': True,
#    'wish': True,
#    'back': True,
#    'also': True,
#    '#lazyweekend': True},
#   'Positive'),
#  ({'miss': True, 'baao': True, ':(': True}, 'Negative'),
#  ({'2chainz': True,
#    'oops': True,
#    'mean': True,
#    'tiny': True,
#    'chat': True,
#    'day': True,
#    'oooops': True,
#    ':-(': True},
#   'Negative'),
#  ({'@guccigirrl_': True, 'luv': True, 'ur': True, 'avi': True, ':)': True},
#   'Positive'),
#  ({'thanks': True,
#    'follow': True,
#    '@rosbailey2_ros': True,
#    '@circuitelec': True,
#    ':)': True},
#   'Positive'),
#  ({'@iambugti_18': True,
#    '<---': True,
#    'ff__special': True,
#    'acha': True,
#    'banda': True,
#    'hai': True,
#    '✌': True,
#    'tweet': True,
#    'bhi': True,
#    'achi': True,
#    'krta': True,
#    'handsome': True,
#    '😂': True,
#    'must': True,
#    'follow': True,
#    ':)': True},
#   'Positive'),
#  ({'week': True,
#    'work': True,
#    'go': True,
#    'far': True,
#    'quick': True,
#    ':(': True},
#   'Negative'),
#  ({'connect': True, 'leave': True, 'company': True, 'alert': True, ':(': True},
#   'Negative'),
#  ({'@garfyville': True,
#    'bath': True,
#    ':)': True,
#    'even': True,
#    '’': True,
#    'wheelie': True,
#    'bin': True,
#    'nowhere': True,
#    'put': True,
#    '@paulmutton': True},
#   'Positive'),
#  ({'forget': True,
#    'every': True,
#    'year': True,
#    'summer': True,
#    'hols': True,
#    'hard': True,
#    '...': True,
#    'spend': True,
#    'day': True,
#    'never': True,
#    'really': True,
#    'conversation': True,
#    'grown': True,
#    'ups': True,
#    ':(': True,
#    '#isolated': True},
#   'Negative'),
#  ({'@trcpqveen': True, 'love': True, 'lil': True, 'baby': True, ':(': True},
#   'Negative'),
#  ({'snapchat': True,
#    'sexyjudy': True,
#    '19': True,
#    '#snapchat': True,
#    '#kikmeboys': True,
#    '#tagsforlikes': True,
#    '#pussy': True,
#    '#gay': True,
#    '#indiemusic': True,
#    '#sexo': True,
#    ':)': True},
#   'Positive'),
#  ({'@myriadphoto': True,
#    'thanks': True,
#    'retweeting': True,
#    '@madsenjewellery': True,
#    'orchard': True,
#    'art': True,
#    'show': True,
#    'super': True,
#    'weekend': True,
#    ':)': True},
#   'Positive'),
#  ({'@nickclark_1': True, 'ahahah': True, "i'll": True, ':)': True},
#   'Positive'),
#  ({'want': True,
#    'say': True,
#    'huge': True,
#    'thanks': True,
#    '@warriorassaults': True,
#    '@uktac': True,
#    '@bollesafety': True,
#    '@mechanix_wear': True,
#    '@airtech_studios': True,
#    '@hexmags': True,
#    '#ff': True,
#    'support': True,
#    ':)': True},
#   'Positive'),
#  ({'@cekimmr_23': True,
#    'welcoma.have': True,
#    'nice': True,
#    'day': True,
#    ':)': True},
#   'Positive'),
#  ({'@taylorswift13': True,
#    '@caradelevingne': True,
#    '@halstonsage': True,
#    '@natandalex': True,
#    'cant': True,
#    'wait': True,
#    ':)': True},
#   'Positive'),
#  ({'@goldennotebook': True,
#    '@johnemichel': True,
#    '@kellyalovell': True,
#    'thanks': True,
#    'lisa': True,
#    ':)': True},
#   'Positive'),
#  ({'delph': True, 'injure': True, 'already': True, ':(': True, '#mcfc': True},
#   'Negative'),
#  ({'ee': True, 'account': True, 'still': True, 'work': True, ':(': True},
#   'Negative'),
#  ({"where's": True, 'denise': True, 'miss': True, ':(': True}, 'Negative'),
#  ({'@anwarlodhi': True,
#    'imran': True,
#    'khan': True,
#    'innocent': True,
#    ':(': True},
#   'Negative'),
#  ({'try': True,
#    'go': True,
#    'movie': True,
#    'tommarow': True,
#    "i'll": True,
#    'pay': True,
#    ':)': True},
#   'Positive'),
#  ({'fuuuuuuuuuck': True, 'jesus': True, '>:(': True}, 'Negative'),
#  ({'laying': True,
#    'greeting': True,
#    'card': True,
#    'range': True,
#    'print': True,
#    'today': True,
#    'love': True,
#    'job': True,
#    ':-)': True},
#   'Positive'),
#  ({'elmhurst': True,
#    'fc': True,
#    ':-(': True,
#    "i'll": True,
#    'always': True,
#    '#etid': True},
#   'Negative'),
#  ({'@max_pen1': True,
#    'fix': True,
#    'thanks': True,
#    'feedback': True,
#    ':)': True},
#   'Positive'),
#  ({'@yadirarpineda': True,
#    'aw': True,
#    'sorry': True,
#    ':(': True,
#    'ok': True,
#    'wake': True,
#    'madi': True},
#   'Negative'),
#  ({'@tonycurran69': True,
#    '@trennakeating': True,
#    'haha': True,
#    'wake': True,
#    'see': True,
#    'typo': True,
#    'shoulda': True,
#    'snark': True,
#    'lessions': True,
#    'stupid': True,
#    'drunk': True,
#    'finger': True,
#    ':d': True},
#   'Positive'),
#  ({'#schoolsoutforsummer': True,
#    'good': True,
#    'luck': True,
#    'fellow': True,
#    '#parents': True,
#    'juggle': True,
#    'work': True,
#    'child': True,
#    ':-)': True,
#    'xx': True},
#   'Positive'),
#  ({'@jaymcguiness': True,
#    ':-(': True,
#    'please': True,
#    'notice': True,
#    'meowkd': True},
#   'Negative'),
#  ({'good': True, 'night': True, ':(': True}, 'Negative'),
#  ({'@janellearg': True, 'get': True, 'tub': True, ':(': True}, 'Negative'),
#  ({'okay': True, ':)': True}, 'Positive'),
#  ({'course': True,
#    'always': True,
#    'miss': True,
#    '@selenagomez': True,
#    'tweeting': True,
#    'spree': True,
#    ':(': True},
#   'Negative'),
#  ({'@ron_boll': True,
#    'hi': True,
#    'saw': True,
#    'u': True,
#    'follow': True,
#    'think': True,
#    'might': True,
#    'like': True,
#    'dark': True,
#    'plz': True,
#    'let': True,
#    'us': True,
#    'know': True,
#    ':)': True},
#   'Positive'),
#  ({"i'm": True,
#    'bored': True,
#    'plea': True,
#    '1': True,
#    'arianator': True,
#    'talk': True,
#    ':(': True},
#   'Negative'),
#  ({'@katsuzie': True,
#    'yes': True,
#    ':-)': True,
#    'since': True,
#    '12th': True,
#    'thing': True},
#   'Positive'),
#  ({'@applemusic': True,
#    'music': True,
#    'keep': True,
#    'pause': True,
#    'randomly': True,
#    'app': True,
#    'open': True,
#    ':(': True},
#   'Negative'),
#  ({'weather': True,
#    'make': True,
#    'want': True,
#    'go': True,
#    'gym': True,
#    '...': True,
#    ':-(': True},
#   'Negative'),
#  ({'friday': True,
#    'night': True,
#    'live': True,
#    '@nrl': True,
#    '@gemchannel': True,
#    'sth': True,
#    'aus': True,
#    'purchase': True,
#    'digital': True,
#    'pas': True,
#    'still': True,
#    'wait': True,
#    'see': True,
#    '@brisbanebroncos': True,
#    'delay': True,
#    ':-(': True},
#   'Negative'),
#  ({'miss': True, 'boyfriend': True, ':-(': True}, 'Negative'),
#  ({'@infispirit_': True, 'lol': True, ':(': True}, 'Negative'),
#  ({'@stepintolifeyvl': True,
#    'amazing': True,
#    'news': True,
#    'enjoy': True,
#    'toy': True,
#    ':)': True},
#   'Positive'),
#  ({'@lampelois': True,
#    'please': True,
#    'follow': True,
#    'return': True,
#    'soon': True,
#    ':)': True,
#    '#tuitutil': True},
#   'Positive'),
#  ({'@ceisoft': True, 'thanks': True, 'fave': True, ':)': True}, 'Positive'),
#  ({'want': True, 'kylie': True, 'jenner': True, 'clothes': True, ':(': True},
#   'Negative'),
#  ({'ah': True,
#    'guy': True,
#    'know': True,
#    'thing': True,
#    '@ceafive': True,
#    'weather': True,
#    'set': True,
#    'sleep': True,
#    'responsibility': True,
#    ':-(': True},
#   'Negative'),
#  ({'1': True,
#    'follow': True,
#    '@jnlazts': True,
#    'u': True,
#    'back': True,
#    ':)': True},
#   'Positive'),
#  ({'felt': True,
#    'bad': True,
#    'irene': True,
#    'forget': True,
#    'go': True,
#    'say': True,
#    ':(': True},
#   'Negative'),
#  ({'still': True,
#    'sad': True,
#    'fix': True,
#    'car': True,
#    'window': True,
#    'bc': True,
#    "can't": True,
#    'drive': True,
#    'anywhere': True,
#    'without': True,
#    'scar': True,
#    "it'll": True,
#    'shatter': True,
#    ':(': True},
#   'Negative'),
#  ({'@rustyrockets': True,
#    'wish': True,
#    'could': True,
#    'come': True,
#    'see': True,
#    'disability': True,
#    'pension': True,
#    'ptsd': True,
#    'make': True,
#    'impossible': True,
#    'physically': True,
#    'financially': True,
#    ':(': True},
#   'Negative'),
#  ({"i'm": True,
#    'gonna': True,
#    'laugh': True,
#    'shake': True,
#    'head': True,
#    'life': True,
#    'fill': True,
#    'lot': True,
#    'amusement': True,
#    ':)': True,
#    'lol': True},
#   'Positive'),
#  ({'@screamqueenlr': True,
#    "that's": True,
#    'fair': True,
#    'enough': True,
#    ':)': True,
#    'rush': True,
#    'back': True,
#    'either': True},
#   'Positive'),
#  ({'@dj_browning': True,
#    "i'm": True,
#    'go': True,
#    'olympic': True,
#    'stadium': True,
#    'tonight': True,
#    'rain': True,
#    ':(': True},
#   'Negative'),
#  ({"i'm": True,
#    'really': True,
#    'excite': True,
#    'picnic': True,
#    'tmrw': True,
#    ':-)': True},
#   'Positive'),
#  ({'surreal': True, ':)': True}, 'Positive'),
#  ({'@woodgate': True, '@littlewok': True, 'enjoy': True, ':)': True},
#   'Positive'),
#  ({'@archiemill98': True,
#    'good': True,
#    'quit': True,
#    'full': True,
#    'time': True,
#    'job': True,
#    'last': True,
#    'week': True,
#    "can't": True,
#    'find': True,
#    'another': True,
#    'one': True,
#    ':(': True},
#   'Negative'),
#  ({'@lucymatthewsss': True,
#    'deal': True,
#    'man': True,
#    'airport': True,
#    'laugh': True,
#    'ask': True,
#    'age': True,
#    'reaally': True,
#    ':(': True},
#   'Negative'),
#  ({'nose': True, 'bruise': True, 'lil': True, ':(': True}, 'Negative'),
#  ({'pray': True, ':(': True}, 'Negative'),
#  ({'@ellierowexo': True,
#    'weather': True,
#    'mad': True,
#    'work': True,
#    ':(': True,
#    '😒': True},
#   'Negative'),
#  ({':(': True, 'wna': True, 'go': True, 'church': True}, 'Negative'),
#  ({'look': True,
#    'arrive': True,
#    'today': True,
#    '...': True,
#    'super': True,
#    'thanks': True,
#    'edwin': True,
#    'elvena': True,
#    'emc': True,
#    'much': True,
#    'appreciate': True,
#    ':d': True},
#   'Positive'),
#  ({'still': True,
#    'really': True,
#    'miss': True,
#    'purple': True,
#    'hair': True,
#    'tie': True,
#    ':(': True},
#   'Negative'),
#  ({'@jadenchaos': True,
#    "i'm": True,
#    'start': True,
#    'grind': True,
#    'yt': True,
#    ':)': True},
#   'Positive'),
#  ({'stock': True, 'sa': True, '1': True, 'hour': True, ':(': True},
#   'Negative'),
#  ({'stu': True, 'deacti̇vated': True, ':(': True}, 'Negative'),
#  ({'every': True, 'way': True, 'like': True, 'jess': True, ':)': True},
#   'Positive'),
#  ({'big': True,
#    'thanks': True,
#    'everyone': True,
#    'without': True,
#    'support': True,
#    ':)': True,
#    '@hit_londoncity': True,
#    '@baxterstorey': True,
#    '@gbcookbook': True,
#    '@bschefacademy': True},
#   'Positive'),
#  ({'@theyingster': True,
#    '@cristianavai3': True,
#    '@afcgramachroi': True,
#    '@goonerlover69': True,
#    '@iwaveback': True,
#    'lol': True,
#    'tire': True,
#    'good': True,
#    'look': True,
#    ':)': True},
#   'Positive'),
#  ({'lagg': True, 'much': True, 'certain': True, 'people': True, ':(': True},
#   'Negative'),
#  ({'@morrisons': True, 'gross': True, ':(': True}, 'Negative'),
#  ({'@burakkrp': True,
#    'hello': True,
#    ':-)': True,
#    'walk': True,
#    'city': True,
#    'install': True,
#    'application': True,
#    'zonzofox': True,
#    'click': True,
#    'link': True,
#    'free': True,
#    ';-)': True},
#   'Positive'),
#  ({'may': True,
#    'brain': True,
#    'tumor': True,
#    'si': True,
#    'vivian': True,
#    ':(': True,
#    '#mmsmalubhangsakit': True},
#   'Negative'),
#  ({'@httpsguitarist': True, 'fback': True, ':)': True}, 'Positive'),
#  ({'@milessi': True,
#    'ruin': True,
#    'game': True,
#    'notice': True,
#    'many': True,
#    'stop': True,
#    'play': True,
#    'regens': True,
#    'look': True,
#    'realistic': True,
#    ':(': True,
#    'shame': True},
#   'Negative'),
#  ({'@oiiverfelicitys': True,
#    'ugh': True,
#    'yuck': True,
#    ':(': True,
#    'make': True,
#    'sure': True,
#    'rest': True,
#    'next': True,
#    'two': True,
#    'day': True},
#   'Negative'),
#  ({'#followfriday': True,
#    '@straz_das': True,
#    '@dcarsoncpa': True,
#    'top': True,
#    'engage': True,
#    'member': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'1': True,
#    'point': True,
#    'close': True,
#    'grand': True,
#    'final': True,
#    ':(': True,
#    'whyyy': True},
#   'Negative'),
#  ({'someone': True,
#    'please': True,
#    'gift': True,
#    '#notanapology': True,
#    ':(': True},
#   'Negative'),
#  ({'someone': True, 'niall': True, 'layout': True, 'give': True, ':(': True},
#   'Negative'),
#  ({'@little_nells': True,
#    'happy': True,
#    'birthday': True,
#    ':)': True,
#    '🎉': True,
#    '🎈': True},
#   'Positive'),
#  ({'@cyjaexlne': True,
#    'good': True,
#    'cause': True,
#    "i'd": True,
#    'like': True,
#    'upload': True,
#    ':)': True},
#   'Positive'),
#  ({'need': True,
#    'special': True,
#    'medicine': True,
#    "son's": True,
#    'kidney': True,
#    "can't": True,
#    'afford': True,
#    'buy': True,
#    'printer': True,
#    'ink': True,
#    'last': True,
#    'week': True,
#    ':(': True},
#   'Negative'),
#  ({'hoping': True,
#    'real': True,
#    ':(': True,
#    '#zayniscomingbackonjuly26': True},
#   'Negative'),
#  ({'weak': True, 'dom': True, ':(': True, 'techniques': True}, 'Negative'),
#  ({'happy': True, 'friday': True, 'everyone': True, ':-)': True}, 'Positive'),
#  ({'id': True,
#    'anything': True,
#    'go': True,
#    'thorpe': True,
#    'park': True,
#    'tomorrow': True,
#    ':(': True},
#   'Negative'),
#  ({'shoulder': True,
#    'pad': True,
#    'mount': True,
#    'inquisitor': True,
#    'finish': True,
#    '...': True,
#    ':)': True,
#    '#cosplay': True,
#    '#cosplayprogress': True,
#    '…': True},
#   'Positive'),
#  ({'@gambl3d': True,
#    'hey': True,
#    'sorry': True,
#    'hear': True,
#    ':(': True,
#    'check': True,
#    'service': True,
#    'status': True,
#    'page': True,
#    '→': True,
#    'gen': True},
#   'Negative'),
#  ({'reckon': True,
#    'chance': True,
#    'see': True,
#    '#t20': True,
#    'action': True,
#    '#taunton': True,
#    'tonight': True,
#    'hopeful': True,
#    'realistic': True,
#    'face': True,
#    ':-(': True},
#   'Negative'),
#  ({'@shahidssuperfan': True,
#    'miss': True,
#    ':(': True,
#    "i'm": True,
#    'busy': True,
#    'week': True},
#   'Negative'),
#  ({'hope': True,
#    'nate': True,
#    'notice': True,
#    'edit': True,
#    'since': True,
#    'make': True,
#    'icon': True,
#    ':)': True},
#   'Positive'),
#  ({'@kaisoography': True,
#    'good': True,
#    'read': True,
#    'promise': True,
#    ':(': True},
#   'Negative'),
#  ({'@teamgtwy': True,
#    'thanks': True,
#    'add': True,
#    'us': True,
#    'list': True,
#    ':)': True,
#    'make': True,
#    'sure': True,
#    'keep': True,
#    'touch': True,
#    'news': True,
#    'light': True,
#    'bulb': True,
#    'corn': True,
#    'waste': True},
#   'Positive'),
#  ({'@mkbhd': True,
#    '@youtube': True,
#    'keep': True,
#    'good': True,
#    'every': True,
#    'update': True,
#    ':)': True},
#   'Positive'),
#  ({'@melonenbrot': True, 'yeah': True, 'tall': True, ':(': True}, 'Negative'),
#  ({'@theogb': True,
#    '@plasticniki': True,
#    '@iggigg': True,
#    '@j4pe5': True,
#    'dude': True,
#    'watch': True,
#    'language': True,
#    ':(': True},
#   'Negative'),
#  ({':-)': True}, 'Positive'),
#  ({'@neillcameron': True,
#    'aw': True,
#    'man': True,
#    'get': True,
#    'good': True,
#    'soon': True,
#    ':(': True},
#   'Negative'),
#  ({'ekk': True, 'giriboy': True, ':(': True}, 'Negative'),
#  ({'also': True,
#    'wanna': True,
#    'go': True,
#    'beach': True,
#    'best': True,
#    'fraand': True,
#    ':(': True,
#    'might': True,
#    'need': True,
#    'new': True,
#    'friend': True,
#    'december': True,
#    'holiday': True,
#    '😬': True},
#   'Negative'),
#  ({'@zoellaftmendes': True,
#    "i'm": True,
#    'gonna': True,
#    'miss': True,
#    'tweet': True,
#    'tl': True,
#    ':(': True,
#    'always': True,
#    'u': True,
#    'come': True,
#    'back': True},
#   'Negative'),
#  ({'summer': True, 'weather': True, 'wua': True, ':-(': True}, 'Negative'),
#  ({'want': True,
#    'pull': True,
#    'nighter': True,
#    "i'm": True,
#    'sleepy': True,
#    'already': True,
#    ':(': True},
#   'Negative'),
#  ({'@louisemillerx': True,
#    '@redshoes4life': True,
#    '@x_kisaragi': True,
#    '@dayvehallam': True,
#    'billy': True,
#    '...': True,
#    ':(': True},
#   'Negative'),
#  ({'cry': True,
#    'nth': True,
#    'time': True,
#    'today': True,
#    ':(': True,
#    'kinda': True,
#    'tire': True,
#    'tho': True,
#    'hay': True,
#    'gonna': True,
#    'life': True},
#   'Negative'),
#  ({'ate': True,
#    'last': True,
#    'cookie': True,
#    'shir': True,
#    '0': True,
#    '>:d': True},
#   'Positive'),
#  ({'@matt_dominguez': True,
#    'appreciate': True,
#    'follow': True,
#    ':)': True,
#    'hear': True,
#    'botanical': True,
#    'soap': True},
#   'Positive'),
#  ({'@littlemix': True, 'please': True, 'follow': True, ':(': True},
#   'Negative'),
#  ({'@beelovley19': True,
#    'wow': True,
#    'hate': True,
#    'u': True,
#    ':(': True,
#    'imy': True},
#   'Negative'),
#  ({'@shikha123poddar': True,
#    'yes': True,
#    'mam': True,
#    ':)': True,
#    '#wsalelove': True},
#   'Positive'),
#  ({'@elmyra': True,
#    'try': True,
#    'support': True,
#    'uk': True,
#    'citizen': True,
#    'sign': True,
#    ':(': True},
#   'Negative'),
#  ({'@bergsonsandra': True, 'get': True, 'big': True, ':-)': True}, 'Positive'),
#  ({'@alyssaa_o': True, 'bestfriend': True, ':)': True, '😌': True}, 'Positive'),
#  ({'stats': True,
#    'day': True,
#    'arrive': True,
#    '4': True,
#    'new': True,
#    'follower': True,
#    'unfollowers': True,
#    ':)': True,
#    'via': True},
#   'Positive'),
#  ({'@selenagomez': True,
#    'noooooo': True,
#    'online': True,
#    'u': True,
#    'tweet': True,
#    'fan': True,
#    ':(': True},
#   'Negative'),
#  ({'stats': True,
#    'week': True,
#    'arrive': True,
#    '1': True,
#    'new': True,
#    'follower': True,
#    'unfollowers': True,
#    ':)': True,
#    'via': True},
#   'Positive'),
#  ({'@shannoneastwood': True,
#    "i'm": True,
#    'workin': True,
#    ':(': True,
#    'get': True,
#    'day': True,
#    'tuesday': True,
#    'tho': True,
#    'haha': True,
#    'x': True},
#   'Negative'),
#  ({'packing': True, 'nightmare': True, ':(': True}, 'Negative'),
#  ({'@wimagazine': True,
#    '@beldragon_r': True,
#    'perfect': True,
#    'time': True,
#    'see': True,
#    'tweet': True,
#    'send': True,
#    'email': True,
#    'info': True,
#    'recently': True,
#    'engage': True,
#    ':d': True},
#   'Positive'),
#  ({'make': True, 'day': True, 'smile': True, ':)': True}, 'Positive'),
#  ({'found': True, 'goodwill': True, 'gold': True, 'today': True, ':-)': True},
#   'Positive'),
#  ({'@memz_dogi': True, "i'm": True, 'join': True, 'right': True, ':d': True},
#   'Positive'),
#  ({'eyyah': True,
#    ':(': True,
#    '@iamabdallahkb': True,
#    '@kings_dughtr': True,
#    'man': True,
#    'utd': True,
#    'bear': True,
#    '...': True,
#    'best': True},
#   'Negative'),
#  ({'@imvkohli': True,
#    'miss': True,
#    'uh': True,
#    'yr': True,
#    '...': True,
#    'cnt': True,
#    'wait': True,
#    'c': True,
#    ':(': True,
#    ":'(": True},
#   'Negative'),
#  ({'muller': True,
#    'sell': True,
#    'quite': True,
#    'obvious': True,
#    'though': True,
#    'still': True,
#    'hope': True,
#    ':(': True,
#    '#mufc': True},
#   'Negative'),
#  ({'hi': True,
#    'dan': True,
#    'bad': True,
#    'dull': True,
#    'overcast': True,
#    'rain': True,
#    'due': True,
#    'late': True,
#    'today': True,
#    ':-(': True},
#   'Negative'),
#  ({'deserve': True, 'shit': True, ':)': True}, 'Positive'),
#  ({'@leagueofknockup': True,
#    'dang': True,
#    ':(': True,
#    'pon': True,
#    'think': True,
#    'time': True,
#    'finally': True,
#    'come': True,
#    'otl': True},
#   'Negative'),
#  ({'shit': True, '10.3': True, 'k': True, ':(': True}, 'Negative'),
#  ({'@douxvictoriammy': True, 'hay': True, ':(': True}, 'Negative'),
#  ({'@liamjenkins21': True,
#    'hey': True,
#    'liam': True,
#    'know': True,
#    'sweet': True,
#    "spot's": True,
#    'around': True,
#    'barnstaple': True,
#    'bideford': True,
#    'stay': True,
#    'day': True,
#    'planning': True,
#    'abit': True,
#    'road': True,
#    'trip': True,
#    ':)': True},
#   'Positive'),
#  ({'oh': True, 'beauty': True, 'world': True, 'water': True, ':)': True},
#   'Positive'),
#  ({"i'm": True, 'gonna': True, 'buy': True, ':)': True}, 'Positive'),
#  ({'@therainbro': True,
#    'also': True,
#    'gl': True,
#    "tonight's": True,
#    'show': True,
#    ':d': True},
#   'Positive'),
#  ({'@gemfeedofficial': True, 'thanks': True, 'retweet': True, ':)': True},
#   'Positive'),
#  ({'want': True,
#    'go': True,
#    'dance': True,
#    'something': True,
#    'someone': True,
#    'pls': True,
#    'take': True,
#    'hike': True,
#    ':(': True},
#   'Negative'),
#  ({'@nezhira': True, 'happy': True, 'birthday': True, ':d': True}, 'Positive'),
#  ({'@pedro7241cw': True,
#    '@xolanimvulana': True,
#    'good': True,
#    'even': True,
#    'see': True,
#    'around': True,
#    ':)': True,
#    'yep': True,
#    'way': True,
#    'live': True,
#    '#freedom': True,
#    '#pistols': True,
#    'move': True},
#   'Positive'),
#  ({'stats': True,
#    'day': True,
#    'arrive': True,
#    '4': True,
#    'new': True,
#    'follower': True,
#    'unfollowers': True,
#    ':)': True,
#    'via': True},
#   'Positive'),
#  ({'@paulmaxey': True,
#    'get': True,
#    'follow': True,
#    'link': True,
#    'find': True,
#    'code': True,
#    ':)': True,
#    'enjoy': True,
#    'tom': True},
#   'Positive'),
#  ({'@kirkherbstreit': True,
#    'braxton': True,
#    'go': True,
#    'pro': True,
#    ':(': True,
#    'feel': True,
#    'bad': True,
#    'urban': True,
#    'unprecedented': True,
#    'brainwashing': True,
#    'see': True,
#    'tebow': True,
#    'alex': True,
#    'smith': True},
#   'Negative'),
#  ({'heed': True, ':(': True}, 'Negative'),
#  ({'@dualityknight': True,
#    '@bravefrontiergl': True,
#    'lol': True,
#    'sorry': True,
#    'ultor': True,
#    'first': True,
#    'hitter': True,
#    '...': True,
#    'favor': True,
#    'much': True,
#    ':)': True},
#   'Positive'),
#  ({'@despiteofficial': True,
#    'listen': True,
#    'last': True,
#    'night': True,
#    ':)': True,
#    'bleed': True,
#    'amazing': True,
#    'track': True,
#    'scotland': True},
#   'Positive'),
#  ({'@totallywonwooed': True,
#    'lol': True,
#    "i'm": True,
#    'lazy': True,
#    'learn': True,
#    'ps': True,
#    ':(': True},
#   'Negative'),
#  ({'@machado_man4': True,
#    '@tashashukla': True,
#    '@cloydrivers': True,
#    'freedom': True,
#    'hangout': True,
#    'whoever': True,
#    'want': True,
#    ':)': True},
#   'Positive'),
#  ({'well': True,
#    'summer': True,
#    ':(': True,
#    'know': True,
#    'last': True,
#    'live': True,
#    'britain': True,
#    '☺': True,
#    '️': True,
#    '😂': True,
#    '😁': True},
#   'Negative'),
#  ({'@sanahaq17': True, 'okay': True, ':d': True}, 'Positive'),
#  ({'@xx_tequila': True, 'twice': True, 'daily': True, ':)': True}, 'Positive'),
#  ({'@nemuuunem': True,
#    "can't": True,
#    'open': True,
#    'door': True,
#    'hard': True,
#    'notice': True,
#    'already': True,
#    'start': True,
#    'song': True,
#    'love': True,
#    'live': True,
#    'fail': True,
#    ':-(': True},
#   'Negative'),
#  ({'ugh': True, 'im': True, 'excited': True, 'make': True, ':(': True},
#   'Negative'),
#  ({'hard': True,
#    'save': True,
#    'live': True,
#    '...': True,
#    ':(': True,
#    '</3': True,
#    '#stexpert': True,
#    '#ripstegi': True,
#    '@bystegi': True},
#   'Negative'),
#  ({'@mercedesbenzind': True,
#    'reason': True,
#    'would': True,
#    'hand': True,
#    'back': True,
#    'spare': True,
#    'tyre': True,
#    'boot': True,
#    '..': True,
#    'otherwise': True,
#    'true': True,
#    'star': True,
#    ':-)': True},
#   'Positive'),
#  ({'nice': True,
#    'one': True,
#    'baz': True,
#    'lucky': True,
#    'work': True,
#    'wonderful': True,
#    'company': True,
#    'people': True,
#    ':-)': True},
#   'Positive'),
#  ({'@atmacamert': True, 'doesnt': True, 'olur': True, ':d': True}, 'Positive'),
#  ({'@gurmeetramrahim': True,
#    '#ourdaughtersourpride': True,
#    'many': True,
#    'congratulations': True,
#    'papa': True,
#    'ji': True,
#    ':)': True},
#   'Positive'),
#  ({'@annayeng': True, 'sorna': True, ':(': True}, 'Negative'),
#  ({'@bttrcpxljp': True,
#    'u': True,
#    'please': True,
#    'give': True,
#    '@tenderkjss': True,
#    'know': True,
#    'im': True,
#    'late': True,
#    'sorry': True,
#    ':(': True},
#   'Negative'),
#  ({'thanks': True,
#    'lesley': True,
#    'lovely': True,
#    'see': True,
#    'fun': True,
#    'france': True,
#    ':)': True},
#   'Positive'),
#  ({'spiritual': True,
#    'ritual': True,
#    'festival': True,
#    'népal': True,
#    'beginning': True,
#    'line-up': True,
#    ':)': True,
#    'leave': True,
#    'see': True,
#    '...': True},
#   'Positive'),
#  ({"i'm": True,
#    'go': True,
#    'cabincrew': True,
#    'interview': True,
#    'langkawi': True,
#    '1st': True,
#    'august': True,
#    ':)': True,
#    'please': True,
#    'wish': True,
#    'luck': True,
#    '@airasia': True,
#    '@tonyfernandes': True},
#   'Positive'),
#  ({'friend': True, ':(': True}, 'Negative'),
#  ({'would': True,
#    'really': True,
#    'appreciate': True,
#    'share': True,
#    'video': True,
#    'around': True,
#    ':)': True},
#   'Positive'),
#  ({'invite': True, 'pin': True, '5878e503': True, ':)': True}, 'Positive'),
#  ({'wish': True, 'honma': True, 'would': True, 'win': True, ':(': True},
#   'Negative'),
#  ({'@colinhalby': True,
#    'thank': True,
#    "can't": True,
#    'wait': True,
#    'make': True,
#    'next': True,
#    'cover': True,
#    ':)': True},
#   'Positive'),
#  ({'phone': True, 'charge': True, '1': True, 'forever': True, ':)': True},
#   'Positive'),
#  ({'@psycothichar': True, 'okay': True, 'start': True, ':d': True},
#   'Positive'),
#  ({'@namwngr': True,
#    'get': True,
#    'one': True,
#    'think': True,
#    'previous': True,
#    ':(': True},
#   'Negative'),
#  ({'hi': True,
#    'bam': True,
#    '@barsandmelody': True,
#    'follow': True,
#    'bestfriend': True,
#    '@969horan696': True,
#    'love': True,
#    'lot': True,
#    ':)': True,
#    'see': True,
#    'warsaw': True,
#    '<3': True,
#    'x2': True},
#   'Positive'),
#  ({'@covtelegraph': True,
#    '@sarajcox': True,
#    'oh': True,
#    'dear': True,
#    '3/10': True,
#    ':-(': True},
#   'Negative'),
#  ({'miss': True, 'boyfriend': True, ':(': True}, 'Negative'),
#  ({'@shahrukh9899': True,
#    '@iammansoorkhan': True,
#    'huh': True,
#    ':(': True,
#    'yes': True},
#   'Negative'),
#  ({'point': True, ':)': True, '#marketing': True, '#branding': True},
#   'Positive'),
#  ({'hate': True,
#    'late': True,
#    'bc': True,
#    'wake': True,
#    'early': True,
#    'end': True,
#    'waste': True,
#    'day': True,
#    ':(': True},
#   'Negative'),
#  ({'@ryanbitchtits': True,
#    'feel': True,
#    'look': True,
#    'good': True,
#    'people': True,
#    "can't": True,
#    'see': True,
#    'tbh': True,
#    'tacky': True,
#    ':(': True},
#   'Negative'),
#  ({'@vengefulmgc': True,
#    'miss': True,
#    'youuuu': True,
#    'kateee': True,
#    ':(': True,
#    'iloveyouu': True,
#    'strong': True,
#    '😘': True},
#   'Negative'),
#  ({'@thevampsbrad': True, 'stand': True, 'cool': True, ':)': True},
#   'Positive'),
#  ({'hi': True,
#    'bam': True,
#    '@barsandmelody': True,
#    'follow': True,
#    'bestfriend': True,
#    '@969horan696': True,
#    'love': True,
#    'lot': True,
#    ':)': True,
#    'see': True,
#    'warsaw': True,
#    '<3': True,
#    'x10': True},
#   'Positive'),
#  ({'@vanessauhhh': True, 'win': True, ':(': True}, 'Negative'),
#  ({'@lampshoponline': True,
#    'ha': True,
#    'love': True,
#    'thank': True,
#    ':-)': True,
#    'exciting': True,
#    'plan': True,
#    '#tgif': True},
#   'Positive'),
#  ({'@zoullgab': True,
#    'frozen': True,
#    'bagus': True,
#    'emang': True,
#    ':(': True},
#   'Negative'),
#  ({'“': True,
#    '@kuskus1': True,
#    '@pamtravel': True,
#    'bet': True,
#    'wonder': True,
#    'happen': True,
#    ':(': True,
#    '”': True,
#    'try': True,
#    'calm': True,
#    'start': True,
#    '🙏🏻': True,
#    '🎂': True},
#   'Negative'),
#  ({'well': True,
#    'interesting': True,
#    'breakfast': True,
#    '…': True,
#    'back': True,
#    'holiday': True,
#    ':)': True},
#   'Positive'),
#  ({'feeling': True,
#    'u': True,
#    'wanna': True,
#    'leave': True,
#    "someone's": True,
#    'open': True,
#    'house': True,
#    ':(': True},
#   'Negative'),
#  ({'really': True,
#    'sleep': True,
#    'night': True,
#    ':(': True,
#    "i'm": True,
#    'different': True,
#    'place': True,
#    'little': True,
#    'colder': True,
#    'hopefully': True,
#    'help': True,
#    'took': True,
#    'med': True},
#   'Negative'),
#  ({'@marthasydenham': True,
#    '@alexxdouglas': True,
#    '@wordpressdotcom': True,
#    'lovely': True,
#    'stuff': True,
#    'need': True,
#    'repeat': True,
#    'relentlessly': True,
#    'approximately': True,
#    'next': True,
#    '5': True,
#    'year': True,
#    ':)': True},
#   'Positive'),
#  ({'wtf': True, 'today': True, '...': True, ':(': True}, 'Negative'),
#  ({':(': True}, 'Negative'),
#  ({'one': True, 'day': True, ':(': True}, 'Negative'),
#  ({'@neogrove': True,
#    ':(': True,
#    'sound': True,
#    'like': True,
#    'reach': True,
#    'level': True},
#   'Negative'),
#  ({'newly': True,
#    'list': True,
#    'ebay': True,
#    'store': True,
#    ':-)': True,
#    '...': True},
#   'Positive'),
#  ({'contact': True,
#    'us': True,
#    'today': True,
#    "we'll": True,
#    'get': True,
#    'city': True,
#    'hotbed': True,
#    'bush': True,
#    'somewhere': True,
#    ':)': True,
#    '#classicassures': True},
#   'Positive'),
#  ({'@misslolitalove': True,
#    "that's": True,
#    'true': True,
#    ':-(': True,
#    'try': True,
#    'get': True,
#    'rid': True,
#    'katie': True,
#    'hopkins': True,
#    'avail': True},
#   'Negative'),
#  ({'true': True, 'doubt': True, ':(': True, '#zayniscomingbackonjuly26': True},
#   'Negative'),
#  ({'@oxits': True,
#    'disappointing': True,
#    'hear': True,
#    'especially': True,
#    'invest': True,
#    'one': True,
#    ':-(': True},
#   'Negative'),
#  ({':)': True, '@kreizi_': True, 'want': True, '#ff': True}, 'Positive'),
#  ({'finally': True,
#    'get': True,
#    'bed': True,
#    ':)': True,
#    'good': True,
#    'night': True,
#    'tweeties': True},
#   'Positive'),
#  ({'@parksooyoungie': True,
#    '@_allypasturan': True,
#    '@gbrllx': True,
#    'aytona': True,
#    'hala': True,
#    'guy': True,
#    'get': True,
#    'ready': True,
#    'na': True,
#    'mathird': True,
#    'wheel': True,
#    ':(': True,
#    'jkjk': True},
#   'Negative'),
#  ({'always': True,
#    'get': True,
#    'like': True,
#    '5': True,
#    '4': True,
#    'piece': True,
#    'spicy': True,
#    'nugget': True,
#    ':(': True},
#   'Negative'),
#  ({'@cutehiddlesmile': True,
#    'u': True,
#    'welcome': True,
#    ':-)': True,
#    '♥': True},
#   'Positive'),
#  ({'amber': True, ':(': True}, 'Negative'),
#  ({'@the_rebel_in_me': True,
#    '@swanqueentacos': True,
#    'awww': True,
#    'imperative': True,
#    ':(': True,
#    '#trmdhesitant': True},
#   'Negative'),
#  ({'@tamitrailscapes': True,
#    'great': True,
#    'weekend': True,
#    'tami': True,
#    'thank': True,
#    ':)': True},
#   'Positive'),
#  ({'always': True,
#    'tweet': True,
#    'hit': True,
#    'snap': True,
#    '...': True,
#    'one': True,
#    'ever': True,
#    'worth': True,
#    'try': True,
#    ':)': True},
#   'Positive'),
#  ({'@mathpro314': True,
#    'hey': True,
#    'wanna': True,
#    'check': True,
#    'ytb': True,
#    'channel': True,
#    'post': True,
#    'gameplays': True,
#    'tutorials': True,
#    ':)': True,
#    'via': True},
#   'Positive'),
#  ({'last': True, 'day': True, ':-(': True}, 'Negative'),
#  ({'🌞': True, ':)': True, 'stay': True, 'perfect': True, 'girly': True},
#   'Positive'),
#  ({'delph': True, ':(': True}, 'Negative'),
#  ({'@officialkeanu': True, '..': True, 'awesome': True, ':)': True},
#   'Positive'),
#  ({'miss': True, 'los': True, ':(': True}, 'Negative'),
#  ({'always': True,
#    'much': True,
#    'fun': True,
#    '4th': True,
#    'hour': True,
#    'get': True,
#    'together': True,
#    ':)': True,
#    'ending': True,
#    'night': True,
#    'ice': True,
#    'cream': True,
#    'xfiles': True,
#    'content': True},
#   'Positive'),
#  ({'@ruy9n_': True, 'want': True, 'rt': True, ':(': True}, 'Negative'),
#  ({'bitin': True, ':(': True, '@jathearebels': True}, 'Negative'),
#  ({'@myungfart': True,
#    'dont': True,
#    'cry': True,
#    'baby': True,
#    'talk': True,
#    ':(': True},
#   'Negative'),
#  ({'8': True,
#    '@bigal_lfc': True,
#    '@suepeace1': True,
#    '5': True,
#    '@bevanns': True,
#    '@susanhorgan1': True,
#    'oh': True,
#    'piggin': True,
#    'go': True,
#    'yer': True,
#    'give': True,
#    'us': True,
#    'peace': True,
#    ':)': True},
#   'Positive'),
#  ({'want': True, 'play': True, 'sims': True, '4': True, ':(': True},
#   'Negative'),
#  ({'@lovetartan': True,
#    'really': True,
#    'sorry': True,
#    'cant': True,
#    'find': True,
#    'image': True,
#    'mention': True,
#    ':(': True},
#   'Negative'),
#  ({'@theladyshelly': True,
#    'haha': True,
#    'feel': True,
#    'naked': True,
#    'without': True,
#    'ole': True,
#    'beardy': True,
#    'tho': True,
#    ':(': True},
#   'Negative'),
#  ({'@mrstethompson': True,
#    'thankyou': True,
#    ':)': True,
#    '@bcmz_uk': True,
#    '@msmmango': True,
#    '@tina_baines': True,
#    '@crownsheringham': True,
#    '@lastminuteusvac': True},
#   'Positive'),
#  ({'#tgif': True, '...': True, 'happy': True, 'friday': True, ':)': True},
#   'Positive'),
#  ({'@princesswhut': True,
#    'followed': True,
#    'thanks': True,
#    '@justinbieber': True,
#    'please': True,
#    ':(': True},
#   'Negative'),
#  ({'waiting': True, 'people': True, 'call': True, 'bigot': True, ':p': True},
#   'Positive'),
#  ({'27': True,
#    'unmarried': True,
#    'float': True,
#    'around': True,
#    'tl': True,
#    'need': True,
#    'kind': True,
#    'pressure': True,
#    'right': True,
#    ':(': True},
#   'Negative'),
#  ({'@celestiaistars': True,
#    'actually': True,
#    'type': True,
#    '11:11': True,
#    'laptop': True,
#    'take': True,
#    'forever': True,
#    'tweet': True,
#    ':(': True},
#   'Negative'),
#  ({'headack': True,
#    'badly': True,
#    'tension': True,
#    'eritation': True,
#    ':(': True},
#   'Negative'),
#  ({'@seniorspazz': True,
#    '@tehsmileys': True,
#    'bore': True,
#    'everything': True,
#    ':d': True},
#   'Positive'),
#  ({'time': True, 'twelvyy': True, 'get': True, 'rude': True, ':(': True},
#   'Negative'),
#  ({'homey': True, ':)': True}, 'Positive'),
#  ({'@lowbatterydc': True,
#    '#djstruthmate': True,
#    're-cap': True,
#    'show': True,
#    'start': True,
#    '11am': True,
#    'uk': True,
#    'time': True,
#    'today': True,
#    'featuring': True,
#    "y'all": True,
#    ':)': True,
#    '#urock': True},
#   'Positive'),
#  ({'@amazonhelp': True,
#    '@amazin': True,
#    '@amazonsupport': True,
#    'contact': True,
#    'whatsoever': True,
#    'anybody': True,
#    ':(': True},
#   'Negative'),
#  ({'stats': True,
#    'week': True,
#    'arrive': True,
#    '1': True,
#    'new': True,
#    'follower': True,
#    'unfollowers': True,
#    ':)': True,
#    'via': True},
#   'Positive'),
#  ({'@araredjeb': True,
#    'welcome': True,
#    ':)': True,
#    'lovely': True,
#    'weekend': True,
#    'izzy': True},
#   'Positive'),
#  ({'@martingarrix': True, 'follow': True, 'already': True, ':(': True},
#   'Negative'),
#  ({'@sophiamascardo': True,
#    'happy': True,
#    'trip': True,
#    'keep': True,
#    'safe': True,
#    'see': True,
#    'soon': True,
#    ':(': True},
#   'Negative'),
#  ({'speaker': True, 'full': True, 'volume': True, ':(': True}, 'Negative'),
#  ({'♛': True,
#    '》': True,
#    'love': True,
#    'much': True,
#    'beli̇eve': True,
#    'wi̇ll': True,
#    'follow': True,
#    'please': True,
#    'justi̇n': True,
#    '@justinbieber': True,
#    ':(': True,
#    'x15': True,
#    '332': True,
#    'ｓｅｅ': True,
#    'ｍｅ': True},
#   'Negative'),
#  ({'#followfriday': True,
#    '@france_espana': True,
#    '@reglisse_menthe': True,
#    '@cci_inter': True,
#    'top': True,
#    'engage': True,
#    'member': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'upside': True, ':d': True}, 'Positive'),
#  ({'@annie_airwolf': True,
#    'someone': True,
#    'put': True,
#    'lawn': True,
#    'chair': True,
#    'tree': True,
#    ':(': True},
#   'Negative'),
#  ({'hey': True,
#    'iphone': True,
#    'dreamer': True,
#    'tanisha': True,
#    '1nonly': True,
#    ':)': True,
#    'wanna': True,
#    'get': True,
#    'iph': True,
#    '0ne': True,
#    '6': True,
#    'free': True,
#    'checkout': True,
#    'bi0': True,
#    'thanks': True},
#   'Positive'),
#  ({'@iangelidaki': True,
#    '@carlhamlet': True,
#    'haha': True,
#    'nothing': True,
#    'stop': True,
#    'goat': True,
#    ':d': True},
#   'Positive'),
#  ({'@kjorobbinsl': True,
#    '@wideglide96': True,
#    '@vivijo86': True,
#    '@beingsomebody11': True,
#    '@sophlicious84': True,
#    '@shaymc3796': True,
#    '@shaymcsharon': True,
#    '@parajanitor': True,
#    '@kelseabellum': True,
#    'thanks': True,
#    ':)': True},
#   'Positive'),
#  ({'r': True, 'back': True, ':)': True}, 'Positive'),
#  ({'love': True, 'u': True, ':p': True}, 'Positive'),
#  ({'@switchingtosave': True,
#    'thanks': True,
#    'follow': True,
#    ':-)': True,
#    'hope': True,
#    'great': True,
#    'week': True},
#   'Positive'),
#  ({'@cat_grl': True,
#    '@uberlinco': True,
#    'guess': True,
#    "they'll": True,
#    'show': True,
#    'german': True,
#    'also': True,
#    'subtitle': True,
#    ':)': True},
#   'Positive'),
#  ({'@moulinparikh': True,
#    'ha': True,
#    'mistake': True,
#    'thanks': True,
#    'point': True,
#    ':)': True},
#   'Positive'),
#  ({'@bridgetminamore': True, 'thrice': True, ':)': True}, 'Positive'),
#  ({'@solodmhelperrs': True,
#    'dont': True,
#    'trade': True,
#    'harry': True,
#    'sorry': True,
#    'one': True,
#    ':(': True},
#   'Negative'),
#  ({'...': True, 'raining': True, 'much': True, 'run': True, ':(': True},
#   'Negative'),
#  ({'@eonnicchi': True,
#    'ask': True,
#    'end': True,
#    '..': True,
#    "i'm": True,
#    'friend': True,
#    ':)': True},
#   'Positive'),
#  ({'@mz_phoi': True,
#    'im': True,
#    'bein': True,
#    'serious': True,
#    'sad': True,
#    '...': True,
#    'lol': True,
#    'go': True,
#    'tla': True,
#    'tweng': True,
#    'ive': True,
#    'get': True,
#    'shit': True,
#    'gene': True,
#    ':(': True},
#   'Negative'),
#  ({'rip': True, 'whitney': True, 'houston': True, ':(': True}, 'Negative'),
#  ({'love': True, 'airport': True, ':-)': True}, 'Positive'),
#  ({'@team_bailona': True, 'thank': True, ':)': True}, 'Positive'),
#  ({'@bumkeyyfel': True,
#    "they're": True,
#    'except': True,
#    'two': True,
#    'kill': True,
#    'people': True,
#    'ene': True},
#   'Negative'),
#  ({'oh': True, 'gfriend': True, 'perform': True, 'rn': True, ':(': True},
#   'Negative'),
#  ({'@dancingsakura': True,
#    'natsuki': True,
#    'often': True,
#    'write': True,
#    'really': True,
#    'catchy': True,
#    'song': True,
#    ':d': True},
#   'Positive'),
#  ({'@alanscottwoods': True,
#    'thanks': True,
#    'head': True,
#    'ear': True,
#    'defender': True,
#    "we're": True,
#    'ready': True,
#    'listen': True,
#    ':)': True,
#    'btw': True,
#    'call': True,
#    'mobile': True,
#    'use': True,
#    '0330 333 7234': True},
#   'Positive'),
#  ({'miss': True, 'seehiah': True, ':(': True, 'omggg': True}, 'Negative'),
#  ({'watching': True, 'joe': True, 'dirt': True, '2': True, ':)': True},
#   'Positive'),
#  ({'@onlytheshelley': True,
#    '6pm': True,
#    'door': True,
#    'open': True,
#    'everyone': True,
#    'vip': True,
#    'general': True,
#    'ticket': True,
#    'get': True,
#    'seat': True,
#    'early': True,
#    'watch': True,
#    'support': True,
#    'act': True,
#    ':)': True},
#   'Positive'),
#  ({'@pinkixx44': True, 'congrats': True, 'pink': True, ':)': True},
#   'Positive'),
#  ({'hello': True,
#    ':)': True,
#    'get': True,
#    'youth': True,
#    'job': True,
#    'opportunities': True,
#    'follow': True,
#    '@tolajobjobs': True,
#    '1': True},
#   'Positive'),
#  ({'@john_bharris': True,
#    '@fakeghostpirate': True,
#    '@f1statman': True,
#    '@xownage133': True,
#    'heritage': True,
#    'sword': True,
#    'make': True,
#    'wood': True,
#    ':d': True},
#   'Positive'),
#  ({'@lunglock': True,
#    '@rhodria': True,
#    '@joseyxneko': True,
#    '@anouilhuk': True,
#    '@davidbedwell': True,
#    '@stupidfacerob': True,
#    '@queenofthesonic': True,
#    '@therealrobcook': True,
#    '@kingrichard76': True,
#    'cheers': True,
#    'alice': True,
#    ':)': True},
#   'Positive'),
#  ({'took': True,
#    'leave': True,
#    'rehearse': True,
#    '@moesg': True,
#    '#youthcelebrate': True,
#    '@sgsportshub': True,
#    'keep': True,
#    'bro': True,
#    '@geraldkoh987': True,
#    'company': True,
#    '@987fm': True,
#    ':)': True},
#   'Positive'),
#  ({'@weeklychris': True, 'hello': True, '...': True, ':(': True}, 'Negative'),
#  ({'officially': True, 'graduated': True, ':d': True}, 'Positive'),
#  ({'@ellierowexo': True,
#    ':(': True,
#    "i'm": True,
#    'litro': True,
#    'gonna': True,
#    'weekend': True},
#   'Negative'),
#  ({'@cultofengineer': True, 'glad': True, ':d': True}, 'Positive'),
#  ({'@diekno26': True,
#    'happy': True,
#    'birthdaaaaayyyy': True,
#    'dinooo': True,
#    ':d': True},
#   'Positive'),
#  ({'@infinityandbion': True, 'funny': True, 'mo': True, ':(': True},
#   'Negative'),
#  ({'@louis_tomlinson': True, 'great': True, 'video': True, ':d': True},
#   'Positive'),
#  ({'suppose': True, 'rain': True, 'weekend': True, ':(': True}, 'Negative'),
#  ({'@kevens': True,
#    "thank's": True,
#    'follow': True,
#    'kevens': True,
#    ':)': True},
#   'Positive'),
#  ({'@riverford': True,
#    'plan': True,
#    'read': True,
#    'brand': True,
#    'new': True,
#    'cook': True,
#    'book': True,
#    'figure': True,
#    'make': True,
#    'dinner': True,
#    'tonight': True,
#    ':)': True},
#   'Positive'),
#  ({'@djtiny_sam': True,
#    ':)': True,
#    'havent': True,
#    'vacation': True,
#    '8': True,
#    'month': True,
#    'xd': True},
#   'Positive'),
#  ({'hi': True,
#    'bam': True,
#    '@barsandmelody': True,
#    'follow': True,
#    'bestfriend': True,
#    '@969horan696': True,
#    'love': True,
#    'lot': True,
#    ':)': True,
#    'see': True,
#    'warsaw': True,
#    '<3': True,
#    'x23': True},
#   'Positive'),
#  ({'stop': True, 'sour': True, ':(': True, 'suit': True, '😂': True, '💞': True},
#   'Negative'),
#  ({'@ohvdqohcdjroc': True,
#    'nope': True,
#    'definitely': True,
#    'still': True,
#    'apply': True,
#    'year': True,
#    'want': True,
#    ':d': True,
#    '#iamca': True},
#   'Positive'),
#  ({'@gculloty87': True, 'thanks': True, ':)': True}, 'Positive'),
#  ({'@denissely': True,
#    'awhh': True,
#    'see': True,
#    'guy': True,
#    "would've": True,
#    'ram': True,
#    'car': True,
#    ':(': True},
#   'Negative'),
#  ({'@amyytherebel': True, ':)': True, 'flawless': True, 'remix': True},
#   'Positive'),
#  ({'find': True,
#    'caramello': True,
#    'koala': True,
#    'get': True,
#    'bar': True,
#    '...': True,
#    ':(': True},
#   'Negative'),
#  ({"can't": True, 'open': True, ':-(': True, 'stockholm': True}, 'Negative'),
#  ({'care': True, ':(': True}, 'Negative'),
#  ({'shaved': True,
#    'hair': True,
#    '..': True,
#    'feel': True,
#    'like': True,
#    'gotta': True,
#    'shave': True,
#    'beard': True,
#    'bit': True,
#    ':(': True,
#    'nooooope': True},
#   'Negative'),
#  ({'guys': True,
#    'add': True,
#    'kik': True,
#    'mune': True,
#    '874': True,
#    '#kik': True,
#    '#kikme': True,
#    '#tagsforlikes': True,
#    '#snapme': True,
#    '#bored': True,
#    '#hannibal': True,
#    '#kikgirl': True,
#    ':(': True},
#   'Negative'),
#  ({'tagal': True, ':(': True}, 'Negative'),
#  ({'@versacelopez': True,
#    'hate': True,
#    'time': True,
#    'zone': True,
#    ':(': True},
#   'Negative'),
#  ({"we're": True, 'get': True, 'old': True, 'baby': True, ':(': True},
#   'Negative'),
#  ({'@brandonherrigan': True,
#    'welcome': True,
#    ':)': True,
#    "when's": True,
#    'next': True,
#    'meet': True},
#   'Positive'),
#  ({'collecting': True,
#    'five': True,
#    'teal': True,
#    'card': True,
#    'time': True,
#    'get': True,
#    'prize': True,
#    'make': True,
#    'sad': True,
#    ':(': True,
#    '#sect': True,
#    '#tennunb': True},
#   'Negative'),
#  ({'great': True, 'night': True, ':d': True}, 'Positive'),
#  ({'fuck': True, 'andy': True, '>:(': True}, 'Negative'),
#  ({'@leandraprins': True,
#    "that's": True,
#    'cool': True,
#    'random': True,
#    'haha': True,
#    'next': True,
#    'time': True,
#    'yell': True,
#    'something': True,
#    ':)': True},
#   'Positive'),
#  ({'@jindaldaily': True, 'pray': True, 'sorry': True, 'happen': True},
#   'Negative'),
#  ({'still': True,
#    'studio': True,
#    'sun': True,
#    'come': True,
#    '...': True,
#    'last': True,
#    'good': True,
#    'morning': True,
#    'arch': True,
#    'camp': True,
#    ':(': True},
#   'Negative'),
#  ({'@daniellesladek': True,
#    'hi': True,
#    'danielle': True,
#    'oh': True,
#    ':(': True,
#    'late': True,
#    'software': True,
#    'instal': True,
#    'try': True,
#    'back': True,
#    'restore': True},
#   'Negative'),
#  ({'@donnamatton': True,
#    'work': True,
#    'keep': True,
#    'smile': True,
#    ':)': True},
#   'Positive'),
#  ({'@taeserasera': True, 'omg': True, 'happen': True, ':(': True}, 'Negative'),
#  ({'#brijresidency': True,
#    'g': True,
#    '6': True,
#    'story': True,
#    'structure': True,
#    '156': True,
#    'unit': True,
#    'encompass': True,
#    '2': True,
#    '3': True,
#    'bhk': True,
#    'flats': True,
#    ':d': True,
#    '91': True,
#    '975-580-4444': True},
#   'Positive'),
#  ({':(': True}, 'Negative'),
#  ({'@avonfvcks': True,
#    'id': True,
#    'grateful': True,
#    'gifted': True,
#    '#notanapology': True,
#    ':-)': True},
#   'Positive'),
#  ({'bad': True,
#    'would': True,
#    'remind': True,
#    'exercise': True,
#    '1:12': True,
#    ':-)': True,
#    'miss': True,
#    'need': True,
#    'come': True,
#    'back': True},
#   'Positive'),
#  ({'@etherealmind': True, 'mental': True, 'strength': True, ':d': True},
#   'Positive'),
#  ({'gutted': True,
#    "can't": True,
#    'get': True,
#    'liverpool': True,
#    'tonight': True,
#    'see': True,
#    '@jakequickenden': True,
#    'final': True,
#    'tour': True,
#    'night': True,
#    'word': True,
#    ':(': True},
#   'Negative'),
#  ({'♛': True,
#    '》': True,
#    'love': True,
#    'much': True,
#    'beli̇eve': True,
#    'wi̇ll': True,
#    'follow': True,
#    'please': True,
#    'justi̇n': True,
#    '@justinbieber': True,
#    ':(': True,
#    'x15': True,
#    '335': True,
#    'ｓｅｅ': True,
#    'ｍｅ': True},
#   'Negative'),
#  ({'@slutwantscock': True, 'dm': True, ':p': True}, 'Positive'),
#  ({'canadian': True,
#    'family': True,
#    'best': True,
#    'dinner': True,
#    'holiday': True,
#    'last': True,
#    'night': True,
#    '@biabistrot': True,
#    'well': True,
#    'enjoyed': True,
#    "we're": True,
#    ':(': True},
#   'Negative'),
#  ({'lonely': True, ':(': True}, 'Negative'),
#  ({'keep': True,
#    'change': True,
#    'fe14': True,
#    'icon': True,
#    'dont': True,
#    'know': True,
#    'one': True,
#    'pick': True,
#    '>:(': True},
#   'Negative'),
#  ({'need': True, 'sleep': True, '...': True, ':(': True}, 'Negative'),
#  ({'3': True,
#    'okk': True,
#    'den': True,
#    'call': True,
#    'abp': True,
#    'n': True,
#    'spread': True,
#    'allover': True,
#    'india': True,
#    'abroad': True,
#    'well': True,
#    ':p': True},
#   'Positive'),
#  ({'stomach': True,
#    'hurt': True,
#    'much': True,
#    'want': True,
#    'cry': True,
#    ':(': True},
#   'Negative'),
#  ({'@triassy': True, 'yelaaaaaaa': True, ':(': True}, 'Negative'),
#  ({'@nuttyxander': True,
#    'make': True,
#    'highlight': True,
#    ':-(': True,
#    'seem': True,
#    'stop': True,
#    'talk': True,
#    'climb': True,
#    'pure': True,
#    'courage': True,
#    'bit': True,
#    'fishy': True},
#   'Negative'),
#  ({'@technobuffalo': True,
#    'check': True,
#    'us': True,
#    ':)': True,
#    'untangling': True,
#    'never': True,
#    'easy': True,
#    '#dtangle': True,
#    '#patent': True,
#    '#innovation': True},
#   'Positive'),
#  ({'@socialrmadrid': True,
#    'actually': True,
#    'gonna': True,
#    'start': True,
#    '1': True,
#    'pm': True,
#    ':)': True},
#   'Positive'),
#  ({'@kriswilliams81': True,
#    'really': True,
#    "that's": True,
#    'great': True,
# ...
#    'sit': True,
#    'quietly': True,
#    'kennel': True,
#    ':(': True,
#    '911': True,
#    'needs': True,
#    '...': True},
#   'Negative'),
#  ({'@dargurl_serwiee': True,
#    'ok': True,
#    'rich': True,
#    'kid': True,
#    'give': True,
#    ':(': True},
#   'Negative'),
#  ({'doli': True,
#    'siregar': True,
#    '@doliphoto': True,
#    'retweeted': True,
#    'tweet': True,
#    'many': True,
#    'thanks': True,
#    'cheers': True,
#    'ninh': True,
#    ':)': True,
#    '#inspire': True},
#   'Positive'),
#  ({'#ff': True,
#    'hopehousekids': True,
#    'pitmantraining': True,
#    'walkersmithway': True,
#    "let's": True,
#    'try': True,
#    '#keepitlocal': True,
#    ':)': True},
#   'Positive'),
#  ({'airport': True, ':(': True}, 'Negative'),
#  ({"i'd": True,
#    'rather': True,
#    'stay': True,
#    'sleep': True,
#    'weekend': True,
#    'go': True,
#    ':(': True},
#   'Negative'),
#  ({'@aiteee1': True,
#    'aitor': True,
#    'sns': True,
#    'would': True,
#    'mind': True,
#    'check': True,
#    'bio': True,
#    'participate': True,
#    'ps4': True,
#    'giveaway': True,
#    'could': True,
#    'winner': True,
#    ':)': True},
#   'Positive'),
#  ({'@iamsrk': True,
#    'please': True,
#    'dont': True,
#    'postpone': True,
#    'long': True,
#    ':(': True},
#   'Negative'),
#  ({'@fawadchaudhry': True,
#    'may': True,
#    'allah': True,
#    'save': True,
#    'us': True,
#    'pakistan': True,
#    'juudiciary': True,
#    ':(': True},
#   'Negative'),
#  ({'@dtoxdliving': True,
#    'wet': True,
#    'miserable': True,
#    ':(': True,
#    '💦': True,
#    '☔': True,
#    '️': True,
#    'miss': True,
#    'morning': True,
#    'yoga': True,
#    'drink': True,
#    'sunshine': True,
#    '🌞': True,
#    '💃🏽': True,
#    '🍹': True,
#    'love': True,
#    'xx': True},
#   'Negative'),
#  ({'yg': True, 'new': True, 'gg': True, 'please': True, ':-(': True},
#   'Negative'),
#  ({'@ryancooperxz': True, ':(': True}, 'Negative'),
#  ({'@21oclock': True,
#    ':(': True,
#    'bout': True,
#    'instant': True,
#    'transmission': True},
#   'Negative'),
#  ({'hello': True,
#    '3': True,
#    'geez': True,
#    '..': True,
#    'badly': True,
#    'miss': True,
#    '12': True,
#    'precious': True,
#    'star': True,
#    ':(': True,
#    'exo': True,
#    '<3': True},
#   'Negative'),
#  ({'twurkin': True,
#    'razzist': True,
#    '1': True,
#    'block': True,
#    'report': True,
#    'u': True,
#    'write': True,
#    'tumblr': True,
#    'post': True,
#    ':(': True},
#   'Negative'),
#  ({'@sgtrumpel': True, 'super': True, ':d': True}, 'Positive'),
#  ({'@markwijs': True, 'every': True, '4': True, 'year': True, ':)': True},
#   'Positive'),
#  ({'feeling': True, 'like': True, 'shit': True, ':-)': True}, 'Positive'),
#  ({'come': True, ':)': True}, 'Positive'),
#  ({'two': True,
#    'hour': True,
#    'still': True,
#    'near': True,
#    'm4': True,
#    'trip': True,
#    '@roalddahlmuseum': True,
#    'abandon': True,
#    ':-(': True},
#   'Negative'),
#  ({'think': True,
#    'mad': True,
#    'bank': True,
#    'paypal': True,
#    'yesterday': True,
#    'royally': True,
#    'fuck': True,
#    "i'm": True,
#    'screw': True,
#    ':(': True},
#   'Negative'),
#  ({'@babygvl': True,
#    'want': True,
#    'kitten': True,
#    'badly': True,
#    'oh': True,
#    'god': True,
#    ':(': True},
#   'Negative'),
#  ({'@woldheath': True,
#    'hand': True,
#    'incorrect': True,
#    'spelling': True,
#    "i'm": True,
#    'apologist': True,
#    ':d': True},
#   'Positive'),
#  ({'#newbethvideo': True,
#    'love': True,
#    'sooo': True,
#    'much': True,
#    '...': True,
#    'live': True,
#    'greece': True,
#    'dont': True,
#    'think': True,
#    "i'm": True,
#    'gonna': True,
#    'win': True,
#    ':(': True,
#    'always': True,
#    'hope': True,
#    '<3': True},
#   'Negative'),
#  ({'lepas': True,
#    'dah': True,
#    'sembuh': True,
#    'ni': True,
#    'sibuk': True,
#    'balik': True,
#    'okay': True,
#    'la': True,
#    'kin': True,
#    'wont': True,
#    'think': True,
#    'anything': True,
#    'else': True,
#    'except': True,
#    'ur': True,
#    'study': True,
#    ':)': True},
#   'Positive'),
#  ({'@thomaslegal': True,
#    'account': True,
#    'mean': True,
#    'hit': True,
#    'us': True,
#    'lunch': True,
#    'time': True,
#    ':(': True},
#   'Negative'),
#  ({"let's": True,
#    'start': True,
#    'chocolate': True,
#    'fudge': True,
#    'coat': True,
#    'superday': True,
#    'chocolatey': True,
#    'super': True,
#    'yasu': True,
#    'way': True,
#    'oooooh': True,
#    'sounds': True,
#    'sexy': True,
#    ':d': True},
#   'Positive'),
#  ({'aw': True, 'bb': True, ':(': True}, 'Negative'),
#  ({'@oloapzurc': True,
#    'damn': True,
#    'hopefully': True,
#    'deserve': True,
#    'one': True,
#    'since': True,
#    'age': True,
#    'last': True,
#    'repack': True,
#    'wont': True,
#    'mention': True,
#    'boy': True,
#    'group': True,
#    'get': True,
#    'repacks': True,
#    'always': True,
#    ':(': True},
#   'Negative'),
#  ({'@oloapzurc': True,
#    'yup': True,
#    'think': True,
#    'gotta': True,
#    'avoid': True,
#    'bb': True,
#    'ic': True,
#    'really': True,
#    'hope': True,
#    'repack': True,
#    ':(': True},
#   'Negative'),
#  ({'@sabal_abla': True,
#    '@tanha_messiah': True,
#    'joke': True,
#    'headline': True,
#    'friend': True,
#    ':(': True,
#    'pls': True,
#    "dn't": True,
#    'brk': True,
#    'heart': True,
#    ":'(": True},
#   'Negative'),
#  ({'@anaateresaa_': True,
#    'baby': True,
#    '😊': True,
#    'next': True,
#    'time': True,
#    'house': True,
#    'whenever': True,
#    ':)': True},
#   'Positive'),
#  ({'@swearlymusic': True,
#    'thank': True,
#    'much': True,
#    'help': True,
#    'spread': True,
#    'word': True,
#    'us': True,
#    'finalist': True,
#    'national': True,
#    'lottery': True,
#    'awards': True,
#    ':-)': True},
#   'Positive'),
#  ({'“': True,
#    'treat': True,
#    'two': True,
#    'different': True,
#    'thing': True,
#    'equal': True,
#    'form': True,
#    'injustice': True,
#    '”': True,
#    '#feminism': True,
#    '#ineedfeminismbecause': True,
#    '..': True,
#    'actually': True,
#    ':p': True},
#   'Positive'),
#  ({'hope': True,
#    'bb': True,
#    'get': True,
#    'proper': True,
#    'rest': True,
#    'soon': True,
#    ':(': True},
#   'Negative'),
#  ({'stats': True,
#    'day': True,
#    'arrive': True,
#    '1': True,
#    'new': True,
#    'follower': True,
#    'unfollowers': True,
#    ':)': True,
#    'via': True},
#   'Positive'),
#  ({'hope': True,
#    'thanks': True,
#    'mfundo': True,
#    ':)': True,
#    '@spexmfanaman': True},
#   'Positive'),
#  ({'@itsrebeccarayne': True, ':d': True, 'ty': True, 'bby': True}, 'Positive'),
#  ({'@neccmatthew': True,
#    'also': True,
#    'sometimes': True,
#    'nice': True,
#    'break': True,
#    'see': True,
#    'constant': True,
#    'tweet': True,
#    'one': True,
#    'subject': True,
#    'welcome': True,
#    ':)': True},
#   'Positive'),
#  ({'wish': True,
#    'twitter': True,
#    'would': True,
#    'support': True,
#    'audio': True,
#    'recording': True,
#    'send': True,
#    'yall': True,
#    'snippet': True,
#    'amaze': True,
#    ':(': True},
#   'Negative'),
#  ({'@jarednotsubway': True,
#    '@iluvmariah': True,
#    '@bravotv': True,
#    'truly': True,
#    'lateral': True,
#    'move': True,
#    'know': True,
#    'queen': True,
#    'bee': True,
#    'upward': True,
#    'bound': True,
#    '#movingonup': True},
#   'Positive'),
#  ({'@ntwenty2': True,
#    '@brasso77': True,
#    'looking': True,
#    'good': True,
#    'guy': True,
#    ':-)': True},
#   'Positive'),
#  ({'@gamedigital': True,
#    "i've": True,
#    'pre': True,
#    'order': True,
#    'r': True,
#    'b': True,
#    'game': True,
#    'watch': True,
#    ':)': True},
#   'Positive'),
#  ({'@kristynlopez97': True,
#    'get': True,
#    'vanilla': True,
#    'latte': True,
#    'though': True,
#    ':(': True},
#   'Negative'),
#  ({'bring': True,
#    '#together': True,
#    '#friends': True,
#    '#family': True,
#    '#loveforfood': True,
#    '#foodforthought': True,
#    '#thoughtfortheday': True,
#    ':)': True},
#   'Positive'),
#  ({'5': True, ':(': True}, 'Negative'),
#  ({'wanna': True, 'watch': True, 'paper': True, 'towns': True, ':(': True},
#   'Negative'),
#  ({'still': True,
#    'havent': True,
#    'find': True,
#    'handsome': True,
#    'jack': True,
#    'draw': True,
#    ':(': True},
#   'Negative'),
#  ({'look': True,
#    'forward': True,
#    'pixels': True,
#    'movie': True,
#    'turn': True,
#    'bummer': True,
#    ':(': True},
#   'Negative'),
#  ({"friend's": True,
#    'lunch': True,
#    '...': True,
#    'yummmm': True,
#    ':)': True,
#    '#nostalgia': True,
#    '#tbs': True,
#    '#ku': True},
#   'Positive'),
#  ({'@normabattle': True,
#    'thx': True,
#    'feedback': True,
#    'glad': True,
#    'gain': True,
#    'value': True,
#    ':)': True},
#   'Positive'),
#  ({'bigbang': True,
#    'need': True,
#    'rest': True,
#    ':(': True,
#    'travel': True,
#    'one': True,
#    'place': True,
#    'another': True,
#    'must': True,
#    'really': True,
#    'tire': True},
#   'Negative'),
#  ({'heartache': True, ':(': True}, 'Negative'),
#  ({'every': True,
#    'night': True,
#    'take': True,
#    'hella': True,
#    'melatonin': True,
#    'like': True,
#    '2-4': True,
#    'hour': True,
#    'nap': True,
#    "i'm": True,
#    'wide': True,
#    'awake': True,
#    'next': True,
#    'day': True,
#    ':(': True},
#   'Negative'),
#  ({'baby': True,
#    'go': True,
#    'back': True,
#    'sleep': True,
#    "i'm": True,
#    'bore': True,
#    ':-(': True},
#   'Negative'),
#  ({'@victoriaskyful': True,
#    '@exo_fanbase': True,
#    'damn': True,
#    'cute': True,
#    ':)': True},
#   'Positive'),
#  ({'1000': True, 'battery': True, 'life': True, 'please': True, ':(': True},
#   'Negative'),
#  ({'@cutelikejdb': True,
#    'followed': True,
#    'thanks': True,
#    '@justinbieber': True,
#    'please': True,
#    ':(': True},
#   'Negative'),
#  ({'ive': True,
#    'get': True,
#    'much': True,
#    'thing': True,
#    '3': True,
#    'day': True,
#    ':(': True,
#    'syawal': True},
#   'Negative'),
#  ({'us': True,
#    '@__karabom': True,
#    '10': True,
#    'loner': True,
#    'side': True,
#    'please': True,
#    ':)': True},
#   'Positive'),
#  ({'@swagonchristian': True, 'trop': True, 'tard': True, ':(': True},
#   'Negative'),
#  ({'@thekimtillman': True, 'road': True, 'trip': True, ':d': True},
#   'Positive'),
#  ({'@silvertom_9': True, 'thanks': True, 'tom': True, ':d': True}, 'Positive'),
#  ({'@yaelapeer': True,
#    '@matthiaslissner': True,
#    '@carlhamlet': True,
#    '@nikkielizdemere': True,
#    '@kikischirr': True,
#    '@preslavrachev': True,
#    'nice': True,
#    'connect': True,
#    'yael': True,
#    ':)': True},
#   'Positive'),
#  ({'@touchdamendes': True,
#    'ok': True,
#    ':(': True,
#    'im': True,
#    'want': True,
#    'talk': True},
#   'Negative'),
#  ({'always': True, 'miss': True, 'something': True, 'wifi': True, ':(': True},
#   'Negative'),
#  ({'bc': True, 'thomas': True, 'tommyy': True, ':(': True}, 'Negative'),
#  ({'go': True,
#    'zumba': True,
#    'somewhere': True,
#    'else': True,
#    'please': True,
#    'study': True,
#    ':(': True},
#   'Negative'),
#  ({'@iamglynnsmith': True,
#    'yeah': True,
#    'find': True,
#    'nhs': True,
#    'dentist': True},
#   'Negative'),
#  ({'dinner': True,
#    'date': True,
#    'tonight': True,
#    'pony': True,
#    'bf': True,
#    ':d': True},
#   'Positive'),
#  ({'@2min4roughing': True,
#    "i'm": True,
#    '22': True,
#    ':)': True,
#    '18': True,
#    'legal': True,
#    'age': True,
#    'drink': True,
#    'much': True,
#    'really': True},
#   'Positive'),
#  ({'whats': True, 'wrong': True, 'nose': True, ':(': True}, 'Negative'),
#  ({'@notch': True,
#    'lemme': True,
#    'know': True,
#    'ever': True,
#    'want': True,
#    'recs': True,
#    'likewise': True,
#    "i'm": True,
#    'always': True,
#    'open': True,
#    'expand': True,
#    'inaccessible': True,
#    'music': True,
#    'library': True,
#    ':d': True},
#   'Positive'),
#  ({'@lukesdagger': True,
#    'joke': True,
#    'lang': True,
#    'eh': True,
#    ':(': True,
#    'hahdhdhshhs': True},
#   'Negative'),
#  ({'cut': True, 'encore': True, ':(': True, '#bad4thwin': True}, 'Negative'),
#  ({'2': True, 'dollar': True, ':(': True, '😭': True}, 'Negative'),
#  ({'many': True, 'thanks': True, ':)': True, 'via': True, '@manoharrpm': True},
#   'Positive'),
#  ({'@uber_ahm': True, ':)': True}, 'Positive'),
#  ({'@tyrafendy': True,
#    'kat': True,
#    'office': True,
#    'client': True,
#    ':(': True},
#   'Negative'),
#  ({'cleanse': True,
#    'scam': True,
#    'ridden': True,
#    'body': True,
#    'vyapam': True,
#    'go': True,
#    'rename': True,
#    'idea': True,
#    ':d': True},
#   'Positive'),
#  ({'@horanshan': True,
#    'barely': True,
#    'use': True,
#    'twitter': True,
#    ':(': True},
#   'Negative'),
#  ({'@fercany': True,
#    '@benjaminharvey': True,
#    'rip': True,
#    'heath': True,
#    'ledger': True,
#    ':(': True},
#   'Negative'),
#  ({'dj': True,
#    'derek': True,
#    'trend': True,
#    'horrible': True,
#    'reason': True,
#    ':(': True,
#    'hope': True,
#    "he's": True,
#    'find': True,
#    'safe': True,
#    'well': True},
#   'Negative'),
#  ({'@rcdeportivo': True,
#    'hello': True,
#    'info': True,
#    'possible': True,
#    'interest': True,
#    'jonathas': True,
#    'close': True,
#    'join': True,
#    'betis': True,
#    ':(': True},
#   'Negative'),
#  ({'@chabeezumba': True,
#    'miss': True,
#    'team': True,
#    'na': True,
#    'coach': True,
#    'training': True,
#    ':(': True},
#   'Negative'),
#  ({'@craig_j_hastie': True,
#    '@massdeception1': True,
#    'uniting': True,
#    'oppress': True,
#    'mass': True,
#    'take': True,
#    'forever': True,
#    ':(': True,
#    'look': True,
#    'wat': True,
#    'happen': True,
#    'n': True,
#    'afghanistn': True,
#    'war': True,
#    'tear': True,
#    'end': True},
#   'Negative'),
#  ({'cute': True, ':(': True}, 'Negative'),
#  ({'@digestdigital': True,
#    'thing': True,
#    'look': True,
#    'great': True,
#    'either': True,
#    'expect': True,
#    'anything': True,
#    'less': True,
#    'lol': True,
#    'least': True,
#    'weekend': True,
#    ':)': True},
#   'Positive'),
#  ({'@kchipongian': True,
#    'yay': True,
#    'thankyou': True,
#    'bonding': True,
#    'ulit': True,
#    'soon': True,
#    ":')": True,
#    ':)': True},
#   'Positive'),
#  ({'@spaqhetto': True,
#    '@artofbsing': True,
#    'little': True,
#    'finger': True,
#    ':d': True},
#   'Positive'),
#  ({'@rafaelallmark': True,
#    'unfollow': True,
#    'please': True,
#    'follow': True,
#    ':(': True,
#    'colombia': True,
#    'love': True},
#   'Negative'),
#  ({'puppy': True, 'broke': True, 'foot': True, ':(': True}, 'Negative'),
#  ({'feel': True, 'free': True, 'share': True, 'others': True, ':-)': True},
#   'Positive'),
#  ({'@24freebird': True,
#    'sorry': True,
#    'bt': True,
#    'mere': True,
#    'pas': True,
#    'link': True,
#    'nhi': True,
#    'hai': True,
#    ':(': True,
#    '@samanthanair23': True},
#   'Negative'),
#  ({'@foowhiter': True,
#    'ugh': True,
#    "i've": True,
#    'never': True,
#    'rt': True,
#    'fade': True,
#    'moan': True,
#    'leeds': True,
#    'tweet': True,
#    ':)': True},
#   'Positive'),
#  ({'@susie299': True,
#    'gorgeous': True,
#    'body': True,
#    ':)': True,
#    'wonder': True,
#    'close': True,
#    '😜': True},
#   'Positive'),
#  ({'@gamehelps': True,
#    'pre': True,
#    'ordered': True,
#    'bo3': True,
#    'get': True,
#    'beta': True,
#    'activation': True,
#    'code': True,
#    'go': True,
#    'cod': True,
#    'website': True,
#    'redeem': True,
#    'say': True,
#    'invalid': True,
#    'help': True,
#    ':(': True},
#   'Negative'),
#  ({'@ibepyari': True, 'follow': True, 'back': True, ':)': True}, 'Positive'),
#  ({'leave': True, 'pcb': True, ':-(': True}, 'Negative'),
#  ({"i've": True,
#    'stream': True,
#    'hour': True,
#    'view': True,
#    'even': True,
#    'budge': True,
#    "i'm": True,
#    'stress': True,
#    ':(': True},
#   'Negative'),
#  ({'@_stevievie': True,
#    "i'll": True,
#    'hawaii': True,
#    'december': True,
#    "we'll": True,
#    'kick': True,
#    'back': True,
#    'miss': True,
#    ':)': True},
#   'Positive'),
#  ({'hi': True,
#    '@bridgehousethel': True,
#    'great': True,
#    'connect': True,
#    'specialise': True,
#    'thermal': True,
#    'image': True,
#    'survey': True,
#    '–': True,
#    'need': True,
#    'us': True,
#    ':)': True},
#   'Positive'),
#  ({'wish': True, 'go': True, 'vidcon': True, ':(': True}, 'Negative'),
#  ({'@theguyliner': True, '@trishie_d': True, 'cool': True, ':d': True},
#   'Positive'),
#  ({'could': True,
#    'please': True,
#    'te': True,
#    'member': True,
#    'auto-followback': True,
#    ':(': True,
#    'thanks': True,
#    '@junjou_rp': True},
#   'Negative'),
#  ...]

# %%
train_data = dataset[:7000]
test_data = dataset[7000:]

# %% [markdown]
# # Bulding Model

# %%
classifir = NaiveBayesClassifier.train(train_data)

# %%
classify.accuracy(classifir, test_data)
# Out:
# 0.9946666666666667

# %%
classifir.show_most_informative_features(20)
# Out:
# Most Informative Features
#                       :( = True           Negati : Positi =   2056.2 : 1.0
#                       :) = True           Positi : Negati =   1654.1 : 1.0
#                 follower = True           Positi : Negati =     39.6 : 1.0
#                   arrive = True           Positi : Negati =     36.9 : 1.0
#                      bam = True           Positi : Negati =     23.3 : 1.0
#                 followed = True           Negati : Positi =     23.3 : 1.0
#                      sad = True           Negati : Positi =     22.9 : 1.0
#                  awesome = True           Positi : Negati =     19.3 : 1.0
#                     poor = True           Negati : Positi =     15.4 : 1.0
#                      via = True           Positi : Negati =     15.2 : 1.0
#                  welcome = True           Positi : Negati =     14.1 : 1.0
#                     blog = True           Positi : Negati =     13.9 : 1.0
#                community = True           Positi : Negati =     13.2 : 1.0
#                     damn = True           Negati : Positi =     12.8 : 1.0
#                      x15 = True           Negati : Positi =     12.8 : 1.0
#                     sick = True           Negati : Positi =     12.4 : 1.0
#                     glad = True           Positi : Negati =     12.0 : 1.0
#                goodnight = True           Positi : Negati =     11.8 : 1.0
#                      ugh = True           Negati : Positi =     11.5 : 1.0
#                     cool = True           Positi : Negati =     11.2 : 1.0

# %%
random_tweet = 'Thank you for sending my baggage to CityX and flying me to CityY at the same time. Brilliant service. #thanksGenericAirline'


cleaning = remove_noise(word_tokenize(random_tweet))

print(cleaning)

print(classifir.classify(dict([token, True] for token in cleaning)))
# Out:
# ['thank', 'you', 'for', 'send', 'my', 'baggage', 'to', 'cityx', 'and', 'fly', 'me', 'to', 'cityy', 'at', 'the', 'same', 'time', 'brilliant', 'service', 'thanksgenericairline']
# Positive

# %%
import pickle

# Save the trained Naive Bayes classifier
with open("sentiment_model.pkl", "wb") as file:
    pickle.dump(classifir, file)

print("Model saved successfully as 'sentiment_model.pkl'")
# Out:
# Model saved successfully as 'sentiment_model.pkl'

# %%
with open("sentiment_model.pkl", "rb") as file:
    loaded_model = pickle.load(file)
